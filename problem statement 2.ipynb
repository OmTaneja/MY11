# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', None)

# %% [markdown]
# # BATSMAN SELECTION

# %%
batsman_df = pd.read_excel("batsman r2.xlsx")
batsman_df.head()
# Out:
#    match id batsman  batsman_id batsman_dob  \
# 0   8587795   AJ Fh       37351  1986-11-17
# 1   8587795   Md Ni      181404  1985-01-01
# 2   8587795   JW Ws     1635773  1988-08-13
# 3   8587795   DR Bs     2170762  1991-04-30
# 4   8587795   AT Cy     2285051  1991-08-27
#
#                               batsman_details  is_batsman_captain  \
# 0  AUS:Right-hand bat:Slow left-arm orthodox:                   1
# 1      AFG:Right-hand bat:Right-arm offbreak:                   0
# 2        AUS:Right-hand bat:Right-arm medium:                   0
# 3  ENG:Right-hand bat:Slow left-arm orthodox:                   0
# 4                     AUS:Left-hand bat:None:                   1
#
#    is_batsman_keeper  inning  runs  balls_faced  over_faced_first wicket kind  \
# 0                  0       2    14           15               1.3         lbw
# 1                  0       2    71           41               6.3         NaN
# 2                  0       1    16           13              17.2         NaN
# 3                  0       1     2            4              19.6      caught
# 4                  1       1    42           25               8.2      caught
#
#   out_by_bowler out_by_fielder  bowler_id  bowler_dob  \
# 0         WA Ar           None  6718844.0  1997-02-05
# 1           NaN           None        NaN         NaN
# 2           NaN           None        NaN         NaN
# 3         KW Rn          Md Ni  1905847.0  1991-02-12
# 4         Id Wm          JA Pe  1594319.0  1988-12-18
#
#                               bowler_details  is_bowler_keeper  \
# 0         AUS:Right-hand bat:Right-arm fast:               0.0
# 1                                        NaN               NaN
# 2                                        NaN               NaN
# 3  AUS:Right-hand bat:Right-arm fast-medium:               0.0
# 4  PAK:Left-hand bat:Slow left-arm orthodox:               0.0
#
#    is_bowler_captain  strike_rate  Fours  Sixes    match_dt  \
# 0                0.0        93.33    1.0    NaN  2021-01-08
# 1                NaN       173.17    9.0    2.0  2021-01-08
# 2                NaN       123.08    1.0    NaN  2021-01-08
# 3                0.0        50.00    NaN    NaN  2021-01-08
# 4                0.0       168.00    3.0    3.0  2021-01-08
#
#   ingestion_timestamp
# 0 2022-03-22 12:43:21
# 1 2022-03-22 12:43:21
# 2 2022-03-22 12:43:21
# 3 2022-03-22 12:43:21
# 4 2022-03-22 12:43:21

# %%
def calculate_metrics(batsman_df):
    batsman_df['half_centuries'] = (batsman_df['runs'] >= 50).astype(int)
    batsman_df['centuries'] = (batsman_df['runs'] >= 100).astype(int)
    
    batsman_stats = batsman_df.groupby('batsman_id').agg({
        'runs': 'sum',
        'half_centuries': 'sum',
        'centuries': 'sum',
        'match id': 'nunique',
        'strike_rate': 'mean'
    }).reset_index()
    batsman_stats.columns = ['batsman_id', 'cumulative_runs', 'half_centuries','centuries','matches','strike_rate']
    
    batsman_stats['average'] = batsman_stats['cumulative_runs'] / batsman_stats['matches']
    
    
    
    #scores assignment
    
    batsman_stats['score_strike'] = np.where(batsman_stats['strike_rate'] >= 150, 50,
                                      np.where((batsman_stats['strike_rate'] >= 100) & (batsman_stats['strike_rate'] < 150), 40,
                                               np.where((batsman_stats['strike_rate'] >= 80) & (batsman_stats['strike_rate'] < 100), 30,
                                                        0)))
    batsman_stats['score_half_centuries'] = np.where(batsman_stats['half_centuries'] >= 5, 20,
                                                     np.where((batsman_stats['half_centuries'] == 3) | (batsman_stats['half_centuries'] == 4), 10,
                                                              np.where((batsman_stats['half_centuries'] == 1) | (batsman_stats['half_centuries'] == 2), 5,
                                                                       0)))
    batsman_stats['score_centuries'] = np.where(batsman_stats['centuries'] >= 3, 30,
                                                     np.where((batsman_stats['centuries'] == 2), 20,
                                                              np.where((batsman_stats['centuries'] == 1), 10,
                                                                       0)))
    
    batsman_stats['score_average'] = np.where(batsman_stats['average'] >= 50, 30,
                                              np.where((batsman_stats['average'] >= 40) & (batsman_stats['average'] < 50), 20,
                                                       np.where((batsman_stats['average'] >= 30) & (batsman_stats['average'] < 40), 10,
                                                                5)))
    
    
    batsman_stats['total_score'] = batsman_stats['score_strike'] + batsman_stats['score_half_centuries'] + batsman_stats['score_centuries'] + batsman_stats['score_average']
    
    return batsman_stats

batsman_stats = calculate_metrics(batsman_df)
batsman_stats
# Out:
#       batsman_id  cumulative_runs  half_centuries  centuries  matches  \
# 0          31464               10               0          0        3
# 1          34061              729               2          0       52
# 2          36665              208               0          0       10
# 3          37351             1517              12          0       65
# 4          41740              976               6          0       41
# ...          ...              ...             ...        ...      ...
# 2058     9822322                0               0          0        1
# 2059     9822392                0               0          0        1
# 2060     9874052               42               0          0        1
# 2061     9883250               20               0          0        1
# 2062     9899140                4               0          0        1
#
#       strike_rate    average  score_strike  score_half_centuries  \
# 0       40.910000   3.333333             0                     0
# 1      119.160577  14.019231            40                     5
# 2       99.854000  20.800000            30                     0
# 3      101.781692  23.338462            40                    20
# 4      116.654878  23.804878            40                    20
# ...           ...        ...           ...                   ...
# 2058     0.000000   0.000000             0                     0
# 2059     0.000000   0.000000             0                     0
# 2060   210.000000  42.000000            50                     0
# 2061    80.000000  20.000000            30                     0
# 2062    40.000000   4.000000             0                     0
#
#       score_centuries  score_average  total_score
# 0                   0              5            5
# 1                   0              5           50
# 2                   0              5           35
# 3                   0              5           65
# 4                   0              5           65
# ...               ...            ...          ...
# 2058                0              5            5
# 2059                0              5            5
# 2060                0             20           70
# 2061                0              5           35
# 2062                0              5            5
#
# [2063 rows x 12 columns]

# %%
selected_batsman = batsman_stats[batsman_stats['cumulative_runs'] > 100]
selected_batsman
# Out:
#       batsman_id  cumulative_runs  half_centuries  centuries  matches  \
# 1          34061              729               2          0       52
# 2          36665              208               0          0       10
# 3          37351             1517              12          0       65
# 4          41740              976               6          0       41
# 5          46794              564               6          0       16
# ...          ...              ...             ...        ...      ...
# 1974     9009265              111               0          0        7
# 1983     9036516              331               2          1       12
# 1987     9047499              162               0          0        7
# 2001     9098571              124               2          0        5
# 2022     9320597              143               0          0        8
#
#       strike_rate    average  score_strike  score_half_centuries  \
# 1      119.160577  14.019231            40                     5
# 2       99.854000  20.800000            30                     0
# 3      101.781692  23.338462            40                    20
# 4      116.654878  23.804878            40                    20
# 5      111.088750  35.250000            40                    20
# ...           ...        ...           ...                   ...
# 1974   133.374286  15.857143            40                     0
# 1983   104.068333  27.583333            40                     5
# 1987    78.822857  23.142857             0                     0
# 2001   148.110000  24.800000            40                     5
# 2022   105.963750  17.875000            40                     0
#
#       score_centuries  score_average  total_score
# 1                   0              5           50
# 2                   0              5           35
# 3                   0              5           65
# 4                   0              5           65
# 5                   0             10           70
# ...               ...            ...          ...
# 1974                0              5           45
# 1983               10              5           60
# 1987                0              5            5
# 2001                0              5           50
# 2022                0              5           45
#
# [786 rows x 12 columns]

# %%
nearbest_11 = pd.read_csv("nearbest_11.csv")

# %%
# calculate consistency
def calculate_consistency_batsman(df, batsman_id):
    batsman_df = df[df['batsman_id'] == batsman_id]

    # Calculate the standard deviation of strike rate
    std_sr = batsman_df['strike_rate'].std()
    
    consistency = {
        'batsman_id': batsman_id,
        'std_strike_rate': std_sr
    }
    
    return consistency

# %%
def calculate_consistency_for_all_batsman(df,df_for_id):
    # Get a list of unique batsman IDs
    batsman_ids = df_for_id['batsman_id']
    
    # Initialize an empty list to store the results
    results = []
    
    # Iterate over each batsman ID and calculate consistency
    for batsman_id in batsman_ids:
        consistency = calculate_consistency_batsman(df, batsman_id)
        results.append(consistency)
    
    # Convert the results list to a DataFrame
    consistency_df = pd.DataFrame(results)
    
    return consistency_df

consistency_df = calculate_consistency_for_all_batsman(batsman_df, selected_batsman)
print(consistency_df)
# Out:
#      batsman_id  std_strike_rate
# 0         34061        87.348364
# 1         36665        52.793254
# 2         37351        52.536959
# 3         41740        53.823271
# 4         46794        56.299157
# ..          ...              ...
# 781     9009265        46.872057
# 782     9036516        65.331280
# 783     9047499        42.086778
# 784     9098571       102.602814
# 785     9320597        56.759101
#
# [786 rows x 2 columns]

# %%
# calculate recency
def calculate_recency_and_performance(df, batsman_id, recent_matches=5):
    # Filter data for the specific batsman
    batsman_df = df[df['batsman_id'] == batsman_id]
    
    # Convert match dates to datetime format
    batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
    
    # Sort the matches by date in descending order to get the most recent matches
    batsman_df = batsman_df.sort_values(by='match_dt', ascending=False)
    
    # Select the most recent matches
    recent_batsman_df = batsman_df.head(recent_matches)
    
    # Calculate recency as the mean of the timestamps of the recent matches
    match_dates = recent_batsman_df['match_dt'].apply(lambda x: x.timestamp())
    recency_score = np.mean(match_dates)
    
    # Summarize performance metrics in recent matches
    total_runs = recent_batsman_df['runs'].sum()
    total_balls_faced = recent_batsman_df['balls_faced'].sum()
    matches_played = len(recent_batsman_df)
    recent_sr = total_runs / total_balls_faced *100 if total_balls_faced > 0 else 0

    
    recency = {
        'batsman_id': batsman_id,
        'recency_score': recency_score,
        'matches_played': matches_played,
        'total_runs': total_runs,
        'total_balls_faced': total_balls_faced,
        'recent_sr': recent_sr
    }
    
    return recency

# %%
def calculate_recency_for_all_batsman(df,df_for_id):
    # Get a list of unique batsman IDs
    batsman_ids = df_for_id['batsman_id']
    
    results = []
    
    # Iterate over each batsman ID and calculate consistency
    for batsman_id in batsman_ids:
        recency = calculate_recency_and_performance(df, batsman_id)
        results.append(recency)
    
    # Convert the results list to a DataFrame
    recency_df = pd.DataFrame(results)
    
    return recency_df

recency_df = calculate_recency_for_all_batsman(batsman_df, selected_batsman)
print(recency_df)
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
#      batsman_id  recency_score  matches_played  total_runs  total_balls_faced  \
# 0         34061   1.673914e+09               5          38                 32
# 1         36665   1.611446e+09               5         158                118
# 2         37351   1.685992e+09               5         128                125
# 3         41740   1.680376e+09               5         116                102
# 4         46794   1.685837e+09               5         230                153
# ..          ...            ...             ...         ...                ...
# 781     9009265   1.679063e+09               5          84                 60
# 782     9036516   1.678614e+09               5         200                112
# 783     9047499   1.691816e+09               5          77                 82
# 784     9098571   1.684904e+09               5         124                 70
# 785     9320597   1.685802e+09               5          91                 65
#
#       recent_sr
# 0    118.750000
# 1    133.898305
# 2    102.400000
# 3    113.725490
# 4    150.326797
# ..          ...
# 781  140.000000
# 782  178.571429
# 783   93.902439
# 784  177.142857
# 785  140.000000
#
# [786 rows x 6 columns]
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])

# %%
c_and_r_batsman  =pd.merge(consistency_df, recency_df, on ='batsman_id')
c_and_r_batsman
# Out:
#      batsman_id  std_strike_rate  recency_score  matches_played  total_runs  \
# 0         34061        87.348364   1.673914e+09               5          38
# 1         36665        52.793254   1.611446e+09               5         158
# 2         37351        52.536959   1.685992e+09               5         128
# 3         41740        53.823271   1.680376e+09               5         116
# 4         46794        56.299157   1.685837e+09               5         230
# ..          ...              ...            ...             ...         ...
# 781     9009265        46.872057   1.679063e+09               5          84
# 782     9036516        65.331280   1.678614e+09               5         200
# 783     9047499        42.086778   1.691816e+09               5          77
# 784     9098571       102.602814   1.684904e+09               5         124
# 785     9320597        56.759101   1.685802e+09               5          91
#
#      total_balls_faced   recent_sr
# 0                   32  118.750000
# 1                  118  133.898305
# 2                  125  102.400000
# 3                  102  113.725490
# 4                  153  150.326797
# ..                 ...         ...
# 781                 60  140.000000
# 782                112  178.571429
# 783                 82   93.902439
# 784                 70  177.142857
# 785                 65  140.000000
#
# [786 rows x 7 columns]

# %%
final_batsman  =pd.merge(c_and_r_batsman, selected_batsman, on ='batsman_id')
final_batsman
# Out:
#      batsman_id  std_strike_rate  recency_score  matches_played  total_runs  \
# 0         34061        87.348364   1.673914e+09               5          38
# 1         36665        52.793254   1.611446e+09               5         158
# 2         37351        52.536959   1.685992e+09               5         128
# 3         41740        53.823271   1.680376e+09               5         116
# 4         46794        56.299157   1.685837e+09               5         230
# ..          ...              ...            ...             ...         ...
# 781     9009265        46.872057   1.679063e+09               5          84
# 782     9036516        65.331280   1.678614e+09               5         200
# 783     9047499        42.086778   1.691816e+09               5          77
# 784     9098571       102.602814   1.684904e+09               5         124
# 785     9320597        56.759101   1.685802e+09               5          91
#
#      total_balls_faced   recent_sr  cumulative_runs  half_centuries  \
# 0                   32  118.750000              729               2
# 1                  118  133.898305              208               0
# 2                  125  102.400000             1517              12
# 3                  102  113.725490              976               6
# 4                  153  150.326797              564               6
# ..                 ...         ...              ...             ...
# 781                 60  140.000000              111               0
# 782                112  178.571429              331               2
# 783                 82   93.902439              162               0
# 784                 70  177.142857              124               2
# 785                 65  140.000000              143               0
#
#      centuries  matches  strike_rate    average  score_strike  \
# 0            0       52   119.160577  14.019231            40
# 1            0       10    99.854000  20.800000            30
# 2            0       65   101.781692  23.338462            40
# 3            0       41   116.654878  23.804878            40
# 4            0       16   111.088750  35.250000            40
# ..         ...      ...          ...        ...           ...
# 781          0        7   133.374286  15.857143            40
# 782          1       12   104.068333  27.583333            40
# 783          0        7    78.822857  23.142857             0
# 784          0        5   148.110000  24.800000            40
# 785          0        8   105.963750  17.875000            40
#
#      score_half_centuries  score_centuries  score_average  total_score
# 0                       5                0              5           50
# 1                       0                0              5           35
# 2                      20                0              5           65
# 3                      20                0              5           65
# 4                      20                0             10           70
# ..                    ...              ...            ...          ...
# 781                     0                0              5           45
# 782                     5               10              5           60
# 783                     0                0              5            5
# 784                     5                0              5           50
# 785                     0                0              5           45
#
# [786 rows x 18 columns]

# %%
low = final_batsman['recency_score'].max()
high = final_batsman['recency_score'].min()
mid = (low+high)/2
final_batsman2 = final_batsman[final_batsman['recency_score']>mid]

# %%
# Adding normalised columns
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
final_batsman2['total_score_normalised'] = scaler.fit_transform(final_batsman2[['total_score']])
final_batsman2['std_sr_normalised'] = scaler.fit_transform(-final_batsman2[['std_strike_rate']])
final_batsman2['recent_sr_normalised'] = scaler.fit_transform(final_batsman2[['recent_sr']])
final_batsman2['recent_matches_played'] = scaler.fit_transform(final_batsman2[['matches_played']])
final_batsman2['sum'] = final_batsman2['std_sr_normalised'] + final_batsman2['recent_sr_normalised'] + final_batsman2['total_score_normalised'] +final_batsman2['recent_matches_played']
final_batsman2
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\117961587.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_batsman2['total_score_normalised'] = scaler.fit_transform(final_batsman2[['total_score']])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\117961587.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_batsman2['std_sr_normalised'] = scaler.fit_transform(-final_batsman2[['std_strike_rate']])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\117961587.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_batsman2['recent_sr_normalised'] = scaler.fit_transform(final_batsman2[['recent_sr']])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\117961587.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_batsman2['recent_matches_played'] = scaler.fit_transform(final_batsman2[['matches_played']])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\117961587.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_batsman2['sum'] = final_batsman2['std_sr_normalised'] + final_batsman2['recent_sr_normalised'] + final_batsman2['total_score_normalised'] +final_batsman2['recent_matches_played']
#      batsman_id  std_strike_rate  recency_score  matches_played  total_runs  \
# 0         34061        87.348364   1.673914e+09               5          38
# 2         37351        52.536959   1.685992e+09               5         128
# 3         41740        53.823271   1.680376e+09               5         116
# 4         46794        56.299157   1.685837e+09               5         230
# 5         62432        62.318474   1.695082e+09               5         115
# ..          ...              ...            ...             ...         ...
# 781     9009265        46.872057   1.679063e+09               5          84
# 782     9036516        65.331280   1.678614e+09               5         200
# 783     9047499        42.086778   1.691816e+09               5          77
# 784     9098571       102.602814   1.684904e+09               5         124
# 785     9320597        56.759101   1.685802e+09               5          91
#
#      total_balls_faced   recent_sr  cumulative_runs  half_centuries  \
# 0                   32  118.750000              729               2
# 2                  125  102.400000             1517              12
# 3                  102  113.725490              976               6
# 4                  153  150.326797              564               6
# 5                   80  143.750000             1911               7
# ..                 ...         ...              ...             ...
# 781                 60  140.000000              111               0
# 782                112  178.571429              331               2
# 783                 82   93.902439              162               0
# 784                 70  177.142857              124               2
# 785                 65  140.000000              143               0
#
#      centuries  matches  strike_rate    average  score_strike  \
# 0            0       52   119.160577  14.019231            40
# 2            0       65   101.781692  23.338462            40
# 3            0       41   116.654878  23.804878            40
# 4            0       16   111.088750  35.250000            40
# 5            0       87   121.130345  21.965517            40
# ..         ...      ...          ...        ...           ...
# 781          0        7   133.374286  15.857143            40
# 782          1       12   104.068333  27.583333            40
# 783          0        7    78.822857  23.142857             0
# 784          0        5   148.110000  24.800000            40
# 785          0        8   105.963750  17.875000            40
#
#      score_half_centuries  score_centuries  score_average  total_score  \
# 0                       5                0              5           50
# 2                      20                0              5           65
# 3                      20                0              5           65
# 4                      20                0             10           70
# 5                      20                0              5           65
# ..                    ...              ...            ...          ...
# 781                     0                0              5           45
# 782                     5               10              5           60
# 783                     0                0              5            5
# 784                     5                0              5           50
# 785                     0                0              5           45
#
#      total_score_normalised  std_sr_normalised  recent_sr_normalised  \
# 0                  0.473684           0.574410              0.471347
# 2                  0.631579           0.775672              0.392642
# 3                  0.631579           0.768236              0.447160
# 4                  0.684211           0.753921              0.623350
# 5                  0.631579           0.719120              0.591691
# ..                      ...                ...                   ...
# 781                0.421053           0.808424              0.573639
# 782                0.578947           0.701702              0.759312
# 783                0.000000           0.836090              0.351737
# 784                0.473684           0.486216              0.752436
# 785                0.421053           0.751262              0.573639
#
#      recent_matches_played       sum
# 0                      1.0  2.519441
# 2                      1.0  2.799893
# 3                      1.0  2.846975
# 4                      1.0  3.061481
# 5                      1.0  2.942390
# ..                     ...       ...
# 781                    1.0  2.803116
# 782                    1.0  3.039962
# 783                    1.0  2.187827
# 784                    1.0  2.712336
# 785                    1.0  2.745954
#
# [637 rows x 23 columns]

# %%
final_sorted = final_batsman2.sort_values(by=['sum'], ascending=[False])
final_sorted.head()
# Out:
#      batsman_id  std_strike_rate  recency_score  matches_played  total_runs  \
# 183     2275195        75.142067   1.702668e+09               5         191
# 164     2162782        58.786308   1.697103e+09               5         233
# 180     2263736        43.395586   1.680670e+09               5         179
# 102     1749075        73.266110   1.699885e+09               5         178
# 290     3125562        64.481831   1.701786e+09               5         201
#
#      total_balls_faced   recent_sr  cumulative_runs  half_centuries  \
# 183                 99  192.929293             2480              17
# 164                149  156.375839             3498              32
# 180                134  133.582090             4031              40
# 102                 99  179.797980             3203              23
# 290                130  154.615385             2551              23
#
#      centuries  matches  strike_rate    average  score_strike  \
# 183          3       95   126.458211  26.105263            40
# 164          6       97   123.307835  36.061856            40
# 180          2       92   115.673261  43.815217            40
# 102          3      112   130.018214  28.598214            40
# 290          4       80   136.978500  31.887500            40
#
#      score_half_centuries  score_centuries  score_average  total_score  \
# 183                    20               30              5           95
# 164                    20               30             10          100
# 180                    20               20             20          100
# 102                    20               30              5           95
# 290                    20               30             10          100
#
#      total_score_normalised  std_sr_normalised  recent_sr_normalised  \
# 183                0.947368           0.644981              0.828428
# 164                1.000000           0.739542              0.652468
# 180                1.000000           0.828523              0.542745
# 102                0.947368           0.655827              0.765217
# 290                1.000000           0.706613              0.643994
#
#      recent_matches_played       sum
# 183                    1.0  3.420777
# 164                    1.0  3.392010
# 180                    1.0  3.371268
# 102                    1.0  3.368412
# 290                    1.0  3.350607

# %%
# comparing with near best 11 provided
bat_best11_df =pd.merge(final_sorted, nearbest_11, left_on='batsman_id', right_on='Player_id', how='inner')
bat_best11_df
# Out:
#    batsman_id  std_strike_rate  recency_score  matches_played  total_runs  \
# 0     2275195        75.142067   1.702668e+09               5         191
# 1      325814        59.241404   1.688291e+09               5         133
# 2     1626526        58.775486   1.697864e+09               5         189
# 3       82228        57.870937   1.686545e+09               5         183
# 4     1506098        61.534111   1.674380e+09               5         209
# 5     4171460        43.931313   1.690917e+09               5          90
# 6     8250115        44.223173   1.699799e+09               5         160
#
#    total_balls_faced   recent_sr  cumulative_runs  half_centuries  centuries  \
# 0                 99  192.929293             2480              17          3
# 1                 82  162.195122              822               8          1
# 2                140  135.000000             2737              18          1
# 3                122  150.000000              874               3          1
# 4                151  138.410596              677               4          1
# 5                 55  163.636364              400               0          0
# 6                152  105.263158              700               6          0
#
#    matches  strike_rate    average  score_strike  score_half_centuries  \
# 0       95   126.458211  26.105263            40                    20
# 1       27   134.665926  30.444444            40                    20
# 2       90   127.727889  30.411111            40                    20
# 3       32   133.901875  27.312500            40                    10
# 4       22   108.984545  30.772727            40                    10
# 5       27   103.976667  14.814815            40                     0
# 6       21   100.807619  33.333333            40                    20
#
#    score_centuries  score_average  total_score  total_score_normalised  \
# 0               30              5           95                0.947368
# 1               10             10           80                0.789474
# 2               10             10           80                0.789474
# 3               10              5           65                0.631579
# 4               10             10           70                0.684211
# 5                0              5           45                0.421053
# 6                0             10           70                0.684211
#
#    std_sr_normalised  recent_sr_normalised  recent_matches_played       sum  \
# 0           0.644981              0.828428                    1.0  3.420777
# 1           0.736911              0.680481                    1.0  3.206865
# 2           0.739604              0.549570                    1.0  3.078648
# 3           0.744834              0.621777                    1.0  2.998189
# 4           0.723655              0.565988                    1.0  2.973854
# 5           0.825426              0.687419                    1.0  2.933897
# 6           0.823739              0.406424                    1.0  2.914374
#
#    Player_id
# 0    2275195
# 1     325814
# 2    1626526
# 3      82228
# 4    1506098
# 5    4171460
# 6    8250115

# %% [markdown]
# # BOWLER SELECTION

# %%
bowler_df = pd.read_excel("bowler r2.xlsx")
bowler_df.head()
# Out:
#    match id bowler  bowler_id  bowler_dob  \
# 0   8587795  PM Se      55299  1984-11-25
# 1   8587795  Md Ni     181404  1985-01-01
# 2   8587795  Id Wm    1594319  1988-12-18
# 3   8587795  KW Rn    1905847  1991-02-12
# 4   8587795  DR Bs    2170762  1991-04-30
#
#                                bowler_details  is_bowler_captain  \
# 0   AUS:Right-hand bat:Right-arm fast-medium:                  0
# 1      AFG:Right-hand bat:Right-arm offbreak:                  0
# 2   PAK:Left-hand bat:Slow left-arm orthodox:                  0
# 3   AUS:Right-hand bat:Right-arm fast-medium:                  0
# 4  ENG:Right-hand bat:Slow left-arm orthodox:                  0
#
#    is_bowler_keeper  inning  runs  wicket_count  balls_bowled  economy  \
# 0                 0       2    38             0            24     9.50
# 1                 0       1     9             0             6     9.00
# 2                 0       1    28             1            24     7.00
# 3                 0       1    40             1            24    10.00
# 4                 0       2    37             1            24     9.25
#
#    maiden  dots  Fours  Sixes  wides  noballs    match_dt ingestion_timestamp
# 0       0     8      4      1      1        0  2021-01-08 2022-03-21 03:44:58
# 1       0     1      1      0      0        0  2021-01-08 2022-03-21 03:44:58
# 2       0     6      3      0      0        0  2021-01-08 2022-03-21 03:44:58
# 3       0    10      2      3      3        0  2021-01-08 2022-03-21 03:44:58
# 4       0     7      4      1      0        0  2021-01-08 2022-03-21 03:44:58

# %%
def calculate_metrics_bowler(bowler_df):
    bowler_df['4w_per_inning'] = ((bowler_df['wicket_count'] == 4) & (bowler_df['inning'] == 1)).astype(int)
    bowler_stats = bowler_df.groupby('bowler_id').agg({
        'wicket_count': 'sum',
        'balls_bowled': 'sum',
        'runs': 'sum',
        '4w_per_inning': 'sum',
        'match id': 'nunique',
        'economy': 'mean'
    }).reset_index()
    bowler_stats.columns = ['bowler_id', 'cumulative_wickets', 'balls_bowled','runs_given','count_4w_per_inning','matches','economy']
    
    bowler_stats['strike_rate_bowl'] = (bowler_stats['balls_bowled'] / bowler_stats['cumulative_wickets'])
    bowler_stats['average_bowl'] = (bowler_stats['runs_given'] / bowler_stats['cumulative_wickets'])
    
    

    #scores assignment
    
    bowler_stats['score_strike_bowl'] = np.where(bowler_stats['strike_rate_bowl'] <= 15, 30,
                                      np.where((bowler_stats['strike_rate_bowl'] > 15) & (bowler_stats['strike_rate_bowl'] <= 19), 20,
                                               np.where((bowler_stats['strike_rate_bowl'] > 19) & (bowler_stats['strike_rate_bowl'] <= 24), 10,
                                                        0)))

    bowler_stats['score_economy'] = np.where(bowler_stats['economy'] <= 3, 50,
                                              np.where((bowler_stats['economy'] > 3) & (bowler_stats['economy'] <= 5), 40,
                                                       np.where((bowler_stats['economy'] > 5) & (bowler_stats['economy'] < 7), 30,
                                                                0)))
    
    
    bowler_stats['score_average_bowl'] = np.where(bowler_stats['average_bowl'] <= 20, 30,
                                              np.where((bowler_stats['average_bowl'] > 20) & (bowler_stats['average_bowl'] <= 30), 20,
                                                       np.where((bowler_stats['average_bowl'] > 30) & (bowler_stats['average_bowl'] <= 40), 10,
                                                                0)))
    bowler_stats['score_4w'] = np.where(bowler_stats['count_4w_per_inning'] >= 4, 30,
                                              np.where((bowler_stats['count_4w_per_inning'] == 2) | (bowler_stats['count_4w_per_inning'] == 3), 20,
                                                       np.where((bowler_stats['count_4w_per_inning'] == 1), 10,
                                                                0)))
    
    
    bowler_stats['total_score_bowl'] = bowler_stats['score_strike_bowl'] + bowler_stats['score_economy'] + bowler_stats['score_average_bowl'] + bowler_stats['score_4w']
    
    return bowler_stats

bowler_stats = calculate_metrics_bowler(bowler_df)
bowler_stats
# Out:
#       bowler_id  cumulative_wickets  balls_bowled  runs_given  \
# 0         34061                  27           635         965
# 1         41740                   5            90          76
# 2         49496                  31           516         533
# 3         55299                  46           709         978
# 4         62432                  72          1178        1418
# ...         ...                 ...           ...         ...
# 1506    9822322                   0            24          29
# 1507    9822392                   3            18           7
# 1508    9822420                   1            12          34
# 1509    9822441                   2            24          57
# 1510    9888584                   1            12          23
#
#       count_4w_per_inning  matches    economy  strike_rate_bowl  average_bowl  \
# 0                       0       46   9.490000         23.518519     35.740741
# 1                       0       10   5.900000         18.000000     15.200000
# 2                       0       23   6.203043         16.645161     17.193548
# 3                       0       35   8.097429         15.413043     21.260870
# 4                       0       77   7.826494         16.361111     19.694444
# ...                   ...      ...        ...               ...           ...
# 1506                    0        2   7.250000               inf           inf
# 1507                    0        1   2.330000          6.000000      2.333333
# 1508                    0        1  17.000000         12.000000     34.000000
# 1509                    0        1  14.250000         12.000000     28.500000
# 1510                    0        1  11.500000         12.000000     23.000000
#
#       score_strike_bowl  score_economy  score_average_bowl  score_4w  \
# 0                    10              0                  10         0
# 1                    20             30                  30         0
# 2                    20             30                  30         0
# 3                    20              0                  20         0
# 4                    20              0                  30         0
# ...                 ...            ...                 ...       ...
# 1506                  0              0                   0         0
# 1507                 30             50                  30         0
# 1508                 30              0                  10         0
# 1509                 30              0                  20         0
# 1510                 30              0                  20         0
#
#       total_score_bowl
# 0                   20
# 1                   80
# 2                   80
# 3                   40
# 4                   50
# ...                ...
# 1506                 0
# 1507               110
# 1508                40
# 1509                50
# 1510                50
#
# [1511 rows x 14 columns]

# %%
selected_bowler = bowler_stats[bowler_stats['cumulative_wickets'] > 10]
selected_bowler
# Out:
#       bowler_id  cumulative_wickets  balls_bowled  runs_given  \
# 0         34061                  27           635         965
# 2         49496                  31           516         533
# 3         55299                  46           709         978
# 4         62432                  72          1178        1418
# 6         65183                  16           189         280
# ...         ...                 ...           ...         ...
# 1378    8833075                  21           225         239
# 1381    8845850                  32           638         866
# 1390    8907338                  47           837        1141
# 1408    8986193                  22           283         338
# 1492    9455557                  15           192         192
#
#       count_4w_per_inning  matches   economy  strike_rate_bowl  average_bowl  \
# 0                       0       46  9.490000         23.518519     35.740741
# 2                       0       23  6.203043         16.645161     17.193548
# 3                       0       35  8.097429         15.413043     21.260870
# 4                       0       77  7.826494         16.361111     19.694444
# 6                       1        9  9.090000         11.812500     17.500000
# ...                   ...      ...       ...               ...           ...
# 1378                    0       11  6.221818         10.714286     11.380952
# 1381                    0       31  8.374194         19.937500     27.062500
# 1390                    1       41  8.232439         17.808511     24.276596
# 1408                    0       13  7.282308         12.863636     15.363636
# 1492                    0        9  6.536667         12.800000     12.800000
#
#       score_strike_bowl  score_economy  score_average_bowl  score_4w  \
# 0                    10              0                  10         0
# 2                    20             30                  30         0
# 3                    20              0                  20         0
# 4                    20              0                  30         0
# 6                    30              0                  30        10
# ...                 ...            ...                 ...       ...
# 1378                 30             30                  30         0
# 1381                 10              0                  20         0
# 1390                 20              0                  20        10
# 1408                 30              0                  30         0
# 1492                 30             30                  30         0
#
#       total_score_bowl
# 0                   20
# 2                   80
# 3                   40
# 4                   50
# 6                   70
# ...                ...
# 1378                90
# 1381                30
# 1390                50
# 1408                60
# 1492                90
#
# [483 rows x 14 columns]

# %%
#calculate consistency
def calculate_consistency_bowler(df, bowler_id):
    # Filter data for the specific bowler
    bowler_df = df[df['bowler_id'] == bowler_id]
    bowler_df = bowler_df[bowler_df['wicket_count'] > 0]

    # Calculate strike rate: balls bowled per wicket taken
    bowler_df['bowler_strike_rate'] = bowler_df['balls_bowled'] / bowler_df['wicket_count']
    
    # Calculate the standard deviation of economy and strike rate
    std_eco = bowler_df['economy'].std()
    std_sr = bowler_df['bowler_strike_rate'].std()

    
    consistency = {
        'bowler_id': bowler_id,
        'std_economy': std_eco,
        'std_bowler_strike_rate': std_sr

    }
    
    return consistency

# %%
def calculate_consistency_for_all_bowlers(df,df_for_id):
    # Get a list of unique bowler IDs
    bowler_ids = df_for_id['bowler_id']
    
    results = []
    
    # Iterate over each bowler ID and calculate consistency
    for bowler_id in bowler_ids:
        consistency = calculate_consistency_bowler(df, bowler_id)
        results.append(consistency)
    
    # Convert the results list to a DataFrame
    consistency_df = pd.DataFrame(results)
    
    return consistency_df

consistency_df_bowl = calculate_consistency_for_all_bowlers(bowler_df,selected_bowler)
print(consistency_df_bowl)
# Out:
#      bowler_id  std_economy  std_bowler_strike_rate
# 0        34061     3.286222                4.904080
# 1        49496     1.922590                8.389912
# 2        55299     2.393895                6.964613
# 3        62432     4.116509                6.374948
# 4        65183     2.733365                4.867898
# ..         ...          ...                     ...
# 478    8833075     2.167391                5.558027
# 479    8845850     2.372230                5.647640
# 480    8907338     2.067828                6.969670
# 481    8986193     2.540279                4.927354
# 482    9455557     2.641248                9.044651
#
# [483 rows x 3 columns]

# %%
# Calculate recency
def calculate_recency_and_performance_bowler(df, bowler_id, recent_matches=5):
    # Filter data for the specific bowler
    bowler_df = df[df['bowler_id'] == bowler_id]
    
    # Convert match dates to datetime format
    bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
    
    # Sort the matches by date in descending order to get the most recent matches
    bowler_df = bowler_df.sort_values(by='match_dt', ascending=False)
    
    # Select the most recent matches
    recent_bowler_df = bowler_df.head(recent_matches)
    
    # Calculate recency as the mean of the timestamps of the recent matches
    match_dates = recent_bowler_df['match_dt'].apply(lambda x: x.timestamp())
    recency_score = np.mean(match_dates)
    
    # Summarize performance metrics in recent matches
    total_wickets = recent_bowler_df['wicket_count'].sum()
    total_runs_conceded = recent_bowler_df['runs'].sum()
    matches_played = len(recent_bowler_df)
    average_runs_conceded = total_runs_conceded / total_wickets if total_wickets > 0 else 0
    
    recency = {
        'bowler_id': bowler_id,
        'recency_score': recency_score,
        'matches_played': matches_played,
        'total_wickets': total_wickets,
        'total_runs_conceded': total_runs_conceded,
        'average_runs_conceded': average_runs_conceded
    }
    
    return recency

# %%
def calculate_recency_for_all_bowlers(df,df_for_id):
    # Get a list of unique bowler IDs
    bowler_ids = df_for_id['bowler_id']
    
    results = []
    
    # Iterate over each bowler ID and calculate consistency
    for bowler_id in bowler_ids:
        recency = calculate_recency_and_performance_bowler(df, bowler_id)
        results.append(recency)
    
    # Convert the results list to a DataFrame
    recency_df = pd.DataFrame(results)
    
    return recency_df

recency_df_bowl = calculate_recency_for_all_bowlers(bowler_df,selected_bowler)
print(recency_df_bowl)
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
#      bowler_id  recency_score  matches_played  total_wickets  \
# 0        34061   1.669075e+09               5              2
# 1        49496   1.680376e+09               5              8
# 2        55299   1.692714e+09               5              3
# 3        62432   1.697034e+09               5              2
# 4        65183   1.625875e+09               5             11
# ..         ...            ...             ...            ...
# 478    8833075   1.688895e+09               5              9
# 479    8845850   1.697138e+09               5              6
# 480    8907338   1.696706e+09               5              5
# 481    8986193   1.680134e+09               5              8
# 482    9455557   1.692334e+09               5             10
#
#      total_runs_conceded  average_runs_conceded
# 0                     73              36.500000
# 1                    119              14.875000
# 2                    150              50.000000
# 3                     90              45.000000
# 4                    158              14.363636
# ..                   ...                    ...
# 478                   77               8.555556
# 479                  162              27.000000
# 480                  148              29.600000
# 481                  145              18.125000
# 482                   72               7.200000
#
# [483 rows x 6 columns]
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])

# %%
c_and_r_bowler  =pd.merge(consistency_df_bowl, recency_df_bowl, on ='bowler_id')
c_and_r_bowler
# Out:
#      bowler_id  std_economy  std_bowler_strike_rate  recency_score  \
# 0        34061     3.286222                4.904080   1.669075e+09
# 1        49496     1.922590                8.389912   1.680376e+09
# 2        55299     2.393895                6.964613   1.692714e+09
# 3        62432     4.116509                6.374948   1.697034e+09
# 4        65183     2.733365                4.867898   1.625875e+09
# ..         ...          ...                     ...            ...
# 478    8833075     2.167391                5.558027   1.688895e+09
# 479    8845850     2.372230                5.647640   1.697138e+09
# 480    8907338     2.067828                6.969670   1.696706e+09
# 481    8986193     2.540279                4.927354   1.680134e+09
# 482    9455557     2.641248                9.044651   1.692334e+09
#
#      matches_played  total_wickets  total_runs_conceded  average_runs_conceded
# 0                 5              2                   73              36.500000
# 1                 5              8                  119              14.875000
# 2                 5              3                  150              50.000000
# 3                 5              2                   90              45.000000
# 4                 5             11                  158              14.363636
# ..              ...            ...                  ...                    ...
# 478               5              9                   77               8.555556
# 479               5              6                  162              27.000000
# 480               5              5                  148              29.600000
# 481               5              8                  145              18.125000
# 482               5             10                   72               7.200000
#
# [483 rows x 8 columns]

# %%
final_bowler  =pd.merge(c_and_r_bowler, selected_bowler, on ='bowler_id')
final_bowler
# Out:
#      bowler_id  std_economy  std_bowler_strike_rate  recency_score  \
# 0        34061     3.286222                4.904080   1.669075e+09
# 1        49496     1.922590                8.389912   1.680376e+09
# 2        55299     2.393895                6.964613   1.692714e+09
# 3        62432     4.116509                6.374948   1.697034e+09
# 4        65183     2.733365                4.867898   1.625875e+09
# ..         ...          ...                     ...            ...
# 478    8833075     2.167391                5.558027   1.688895e+09
# 479    8845850     2.372230                5.647640   1.697138e+09
# 480    8907338     2.067828                6.969670   1.696706e+09
# 481    8986193     2.540279                4.927354   1.680134e+09
# 482    9455557     2.641248                9.044651   1.692334e+09
#
#      matches_played  total_wickets  total_runs_conceded  \
# 0                 5              2                   73
# 1                 5              8                  119
# 2                 5              3                  150
# 3                 5              2                   90
# 4                 5             11                  158
# ..              ...            ...                  ...
# 478               5              9                   77
# 479               5              6                  162
# 480               5              5                  148
# 481               5              8                  145
# 482               5             10                   72
#
#      average_runs_conceded  cumulative_wickets  balls_bowled  runs_given  \
# 0                36.500000                  27           635         965
# 1                14.875000                  31           516         533
# 2                50.000000                  46           709         978
# 3                45.000000                  72          1178        1418
# 4                14.363636                  16           189         280
# ..                     ...                 ...           ...         ...
# 478               8.555556                  21           225         239
# 479              27.000000                  32           638         866
# 480              29.600000                  47           837        1141
# 481              18.125000                  22           283         338
# 482               7.200000                  15           192         192
#
#      count_4w_per_inning  matches   economy  strike_rate_bowl  average_bowl  \
# 0                      0       46  9.490000         23.518519     35.740741
# 1                      0       23  6.203043         16.645161     17.193548
# 2                      0       35  8.097429         15.413043     21.260870
# 3                      0       77  7.826494         16.361111     19.694444
# 4                      1        9  9.090000         11.812500     17.500000
# ..                   ...      ...       ...               ...           ...
# 478                    0       11  6.221818         10.714286     11.380952
# 479                    0       31  8.374194         19.937500     27.062500
# 480                    1       41  8.232439         17.808511     24.276596
# 481                    0       13  7.282308         12.863636     15.363636
# 482                    0        9  6.536667         12.800000     12.800000
#
#      score_strike_bowl  score_economy  score_average_bowl  score_4w  \
# 0                   10              0                  10         0
# 1                   20             30                  30         0
# 2                   20              0                  20         0
# 3                   20              0                  30         0
# 4                   30              0                  30        10
# ..                 ...            ...                 ...       ...
# 478                 30             30                  30         0
# 479                 10              0                  20         0
# 480                 20              0                  20        10
# 481                 30              0                  30         0
# 482                 30             30                  30         0
#
#      total_score_bowl
# 0                  20
# 1                  80
# 2                  40
# 3                  50
# 4                  70
# ..                ...
# 478                90
# 479                30
# 480                50
# 481                60
# 482                90
#
# [483 rows x 21 columns]

# %%
final_bowler2 = final_bowler[final_bowler['recency_score']>1680000000]

# %%
# Adding normalised columns
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
final_bowler2['total_score_bowler_normalised'] = scaler.fit_transform(final_bowler2[['total_score_bowl']])
final_bowler2['std_bowler_economy_normalised'] = scaler.fit_transform(-final_bowler2[['std_economy']])
final_bowler2['recent_average_normalised'] = scaler.fit_transform(-final_bowler2[['average_runs_conceded']])
final_bowler2['sum'] = final_bowler2['total_score_bowler_normalised'] + final_bowler2['recent_average_normalised'] + final_bowler2['std_bowler_economy_normalised']
final_bowler2
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\4186563684.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_bowler2['total_score_bowler_normalised'] = scaler.fit_transform(final_bowler2[['total_score_bowl']])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\4186563684.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_bowler2['std_bowler_economy_normalised'] = scaler.fit_transform(-final_bowler2[['std_economy']])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\4186563684.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_bowler2['recent_average_normalised'] = scaler.fit_transform(-final_bowler2[['average_runs_conceded']])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\4186563684.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_bowler2['sum'] = final_bowler2['total_score_bowler_normalised'] + final_bowler2['recent_average_normalised'] + final_bowler2['std_bowler_economy_normalised']
#      bowler_id  std_economy  std_bowler_strike_rate  recency_score  \
# 1        49496     1.922590                8.389912   1.680376e+09
# 2        55299     2.393895                6.964613   1.692714e+09
# 3        62432     4.116509                6.374948   1.697034e+09
# 5        74087     1.891041                6.192313   1.689863e+09
# 6        74367     1.683813                6.472377   1.680947e+09
# ..         ...          ...                     ...            ...
# 478    8833075     2.167391                5.558027   1.688895e+09
# 479    8845850     2.372230                5.647640   1.697138e+09
# 480    8907338     2.067828                6.969670   1.696706e+09
# 481    8986193     2.540279                4.927354   1.680134e+09
# 482    9455557     2.641248                9.044651   1.692334e+09
#
#      matches_played  total_wickets  total_runs_conceded  \
# 1                 5              8                  119
# 2                 5              3                  150
# 3                 5              2                   90
# 5                 5              7                   99
# 6                 5              7                  122
# ..              ...            ...                  ...
# 478               5              9                   77
# 479               5              6                  162
# 480               5              5                  148
# 481               5              8                  145
# 482               5             10                   72
#
#      average_runs_conceded  cumulative_wickets  balls_bowled  runs_given  \
# 1                14.875000                  31           516         533
# 2                50.000000                  46           709         978
# 3                45.000000                  72          1178        1418
# 5                14.142857                  30           609         790
# 6                17.428571                  15           260         344
# ..                     ...                 ...           ...         ...
# 478               8.555556                  21           225         239
# 479              27.000000                  32           638         866
# 480              29.600000                  47           837        1141
# 481              18.125000                  22           283         338
# 482               7.200000                  15           192         192
#
#      count_4w_per_inning  matches   economy  strike_rate_bowl  average_bowl  \
# 1                      0       23  6.203043         16.645161     17.193548
# 2                      0       35  8.097429         15.413043     21.260870
# 3                      0       77  7.826494         16.361111     19.694444
# 5                      0       42  8.110000         20.300000     26.333333
# 6                      0       14  8.254286         17.333333     22.933333
# ..                   ...      ...       ...               ...           ...
# 478                    0       11  6.221818         10.714286     11.380952
# 479                    0       31  8.374194         19.937500     27.062500
# 480                    1       41  8.232439         17.808511     24.276596
# 481                    0       13  7.282308         12.863636     15.363636
# 482                    0        9  6.536667         12.800000     12.800000
#
#      score_strike_bowl  score_economy  score_average_bowl  score_4w  \
# 1                   20             30                  30         0
# 2                   20              0                  20         0
# 3                   20              0                  30         0
# 5                   10              0                  20         0
# 6                   20              0                  20         0
# ..                 ...            ...                 ...       ...
# 478                 30             30                  30         0
# 479                 10              0                  20         0
# 480                 20              0                  20        10
# 481                 30              0                  30         0
# 482                 30             30                  30         0
#
#      total_score_bowl  total_score_bowler_normalised  \
# 1                  80                            0.8
# 2                  40                            0.4
# 3                  50                            0.5
# 5                  30                            0.3
# 6                  40                            0.4
# ..                ...                            ...
# 478                90                            0.9
# 479                30                            0.3
# 480                50                            0.5
# 481                60                            0.6
# 482                90                            0.9
#
#      std_bowler_economy_normalised  recent_average_normalised       sum
# 1                         0.728479                   0.907031  2.435510
# 2                         0.604216                   0.687500  1.691716
# 3                         0.150037                   0.718750  1.368787
# 5                         0.736797                   0.911607  1.948404
# 6                         0.791434                   0.891071  2.082506
# ..                             ...                        ...       ...
# 478                       0.663936                   0.946528  2.510464
# 479                       0.609929                   0.831250  1.741179
# 480                       0.690186                   0.815000  2.005186
# 481                       0.565621                   0.886719  2.052340
# 482                       0.539000                   0.955000  2.394000
#
# [310 rows x 25 columns]

# %%
final_sorted_bowler = final_bowler2.sort_values(by=['sum'], ascending=[False])
final_sorted_bowler.head()
# Out:
#      bowler_id  std_economy  std_bowler_strike_rate  recency_score  \
# 463    8246440     1.534747                7.970315   1.698123e+09
# 202    3633503     1.134196                7.277820   1.692818e+09
# 464    8246573     1.832357                6.231401   1.689708e+09
# 396    7276380     1.610741                5.771812   1.692040e+09
# 478    8833075     2.167391                5.558027   1.688895e+09
#
#      matches_played  total_wickets  total_runs_conceded  \
# 463               5              9                   97
# 202               5              8                   93
# 464               5             10                  125
# 396               5             10                  129
# 478               5              9                   77
#
#      average_runs_conceded  cumulative_wickets  balls_bowled  runs_given  \
# 463              10.777778                  23           247         214
# 202              11.625000                  11           174         163
# 464              12.500000                  14           151         167
# 396              12.900000                  46           553         746
# 478               8.555556                  21           225         239
#
#      count_4w_per_inning  matches   economy  strike_rate_bowl  average_bowl  \
# 463                    1       12  5.320000         10.739130      9.304348
# 202                    0       10  5.841000         15.818182     14.818182
# 464                    0        7  6.820000         10.785714     11.928571
# 396                    2       28  8.255357         12.021739     16.217391
# 478                    0       11  6.221818         10.714286     11.380952
#
#      score_strike_bowl  score_economy  score_average_bowl  score_4w  \
# 463                 30             30                  30        10
# 202                 20             30                  30         0
# 464                 30             30                  30         0
# 396                 30              0                  30        20
# 478                 30             30                  30         0
#
#      total_score_bowl  total_score_bowler_normalised  \
# 463               100                            1.0
# 202                80                            0.8
# 464                90                            0.9
# 396                80                            0.8
# 478                90                            0.9
#
#      std_bowler_economy_normalised  recent_average_normalised       sum
# 463                       0.830737                   0.932639  2.763375
# 202                       0.936345                   0.927344  2.663688
# 464                       0.752270                   0.921875  2.574145
# 396                       0.810700                   0.919375  2.530075
# 478                       0.663936                   0.946528  2.510464

# %%
# comparing with near best 11 provided
bowl_best11_df =pd.merge(final_sorted_bowler, nearbest_11, left_on='bowler_id', right_on='Player_id', how='inner')
bowl_best11_df
# Out:
#    bowler_id  std_economy  std_bowler_strike_rate  recency_score  \
# 0    8246573     1.832357                6.231401   1.689708e+09
# 1    8986193     2.540279                4.927354   1.680134e+09
# 2    4171460     1.200602                8.335030   1.690554e+09
# 3    7758638     2.049473                6.604893   1.692438e+09
# 4    2275195     3.386464                6.131763   1.699678e+09
#
#    matches_played  total_wickets  total_runs_conceded  average_runs_conceded  \
# 0               5             10                  125              12.500000
# 1               5              8                  145              18.125000
# 2               5              5                  140              28.000000
# 3               5              6                  145              24.166667
# 4               5              5                  146              29.200000
#
#    cumulative_wickets  balls_bowled  runs_given  count_4w_per_inning  matches  \
# 0                  14           151         167                    0        7
# 1                  22           283         338                    0       13
# 2                  21           462         631                    1       26
# 3                  40           951        1137                    0       42
# 4                  36           882        1154                    0       68
#
#     economy  strike_rate_bowl  average_bowl  score_strike_bowl  score_economy  \
# 0  6.820000         10.785714     11.928571                 30             30
# 1  7.282308         12.863636     15.363636                 30              0
# 2  8.708462         22.000000     30.047619                 10              0
# 3  7.389762         23.775000     28.425000                 10              0
# 4  8.365588         24.500000     32.055556                  0              0
#
#    score_average_bowl  score_4w  total_score_bowl  \
# 0                  30         0                90
# 1                  30         0                60
# 2                  10        10                30
# 3                  20         0                30
# 4                  10         0                10
#
#    total_score_bowler_normalised  std_bowler_economy_normalised  \
# 0                            0.9                       0.752270
# 1                            0.6                       0.565621
# 2                            0.3                       0.918836
# 3                            0.3                       0.695026
# 4                            0.1                       0.342519
#
#    recent_average_normalised       sum  Player_id
# 0                   0.921875  2.574145    8246573
# 1                   0.886719  2.052340    8986193
# 2                   0.825000  2.043836    4171460
# 3                   0.848958  1.843984    7758638
# 4                   0.817500  1.260019    2275195

# %% [markdown]
# # WICKET KEEPER SELECTION

# %% [markdown]
# # not taking into account "is_bowler_keeper" because wk are judged based on their batsman score

# %%
def calculate_metrics(batsman_df):
    batsman_df['half_centuries'] = (batsman_df['runs'] >= 50).astype(int)
    batsman_df['centuries'] = (batsman_df['runs'] >= 100).astype(int)
    
    batsman_stats = batsman_df.groupby('batsman_id').agg({
        'runs': 'sum',
        'half_centuries': 'sum',
        'centuries': 'sum',
        'match id': 'nunique',
        'strike_rate': 'mean',
        'is_batsman_keeper': 'sum', 
    }).reset_index()
    batsman_stats.columns = ['batsman_id', 'cumulative_runs', 'half_centuries','centuries','matches','strike_rate','is_batsman_keeper']
    
    batsman_stats['average'] = batsman_stats['cumulative_runs'] / batsman_stats['matches']
    
    #scores assignment
    batsman_stats['score_strike'] = np.where(batsman_stats['strike_rate'] >= 150, 50,
                                      np.where((batsman_stats['strike_rate'] >= 100) & (batsman_stats['strike_rate'] < 150), 40,
                                               np.where((batsman_stats['strike_rate'] >= 80) & (batsman_stats['strike_rate'] < 100), 30,
                                                        0)))
    batsman_stats['score_half_centuries'] = np.where(batsman_stats['half_centuries'] >= 5, 20,
                                                     np.where((batsman_stats['half_centuries'] == 3) | (batsman_stats['half_centuries'] == 4), 10,
                                                              np.where((batsman_stats['half_centuries'] == 1) | (batsman_stats['half_centuries'] == 2), 5,
                                                                       0)))
    batsman_stats['score_centuries'] = np.where(batsman_stats['centuries'] >= 3, 30,
                                                     np.where((batsman_stats['centuries'] == 2), 20,
                                                              np.where((batsman_stats['centuries'] == 1), 10,
                                                                       0)))
    
    batsman_stats['score_average'] = np.where(batsman_stats['average'] >= 50, 30,
                                              np.where((batsman_stats['average'] >= 40) & (batsman_stats['average'] < 50), 20,
                                                       np.where((batsman_stats['average'] >= 30) & (batsman_stats['average'] < 40), 10,
                                                                5)))
    
    
    batsman_stats['total_score'] = batsman_stats['score_strike'] + batsman_stats['score_half_centuries'] + batsman_stats['score_centuries'] + batsman_stats['score_average']
    wk_stats = batsman_stats[(batsman_stats['is_batsman_keeper'] >= 2 ) & (batsman_stats['matches'] >= 2)]
    return wk_stats

wk_stats = calculate_metrics(batsman_df)
wk_stats
# Out:
#       batsman_id  cumulative_runs  half_centuries  centuries  matches  \
# 18         87163               24               0          0        2
# 27        150093              506               2          0       39
# 46        196580              338               1          0       27
# 50        210328              980               2          0       59
# 51        211658              140               1          0        4
# ...          ...              ...             ...        ...      ...
# 2003     9103996               17               0          0        3
# 2013     9227455               17               0          0        2
# 2015     9245319               14               0          0        3
# 2026     9346861               45               0          0        3
# 2052     9822259               52               0          0        2
#
#       strike_rate  is_batsman_keeper    average  score_strike  \
# 18      81.110000                  2  12.000000            30
# 27     115.135128                 39  12.974359            40
# 46     126.612593                 27  12.518519            40
# 50     137.973559                 48  16.610169            40
# 51      84.737500                  4  35.000000            30
# ...           ...                ...        ...           ...
# 2003    44.443333                  3   5.666667             0
# 2013    73.160000                  2   8.500000             0
# 2015   103.333333                  2   4.666667            40
# 2026    97.060000                  3  15.000000            30
# 2052   214.285000                  2  26.000000            50
#
#       score_half_centuries  score_centuries  score_average  total_score
# 18                       0                0              5           35
# 27                       5                0              5           50
# 46                       5                0              5           50
# 50                       5                0              5           50
# 51                       5                0             10           45
# ...                    ...              ...            ...          ...
# 2003                     0                0              5            5
# 2013                     0                0              5            5
# 2015                     0                0              5           45
# 2026                     0                0              5           35
# 2052                     0                0              5           55
#
# [196 rows x 13 columns]

# %%
# calculate consistency
consistency_df_wk = calculate_consistency_for_all_batsman(batsman_df, wk_stats)
print(consistency_df_wk)
# Out:
#      batsman_id  std_strike_rate
# 0         87163        58.138320
# 1        150093        98.718005
# 2        196580        95.421785
# 3        210328        92.617033
# 4        211658        29.569459
# ..          ...              ...
# 191     9103996        34.691765
# 192     9227455        20.279822
# 193     9245319        55.075705
# 194     9346861        45.661042
# 195     9822259        20.202041
#
# [196 rows x 2 columns]

# %%
# calculate recency
recency_df_wk = calculate_recency_for_all_batsman(batsman_df,wk_stats)
print(recency_df_wk)
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
#      batsman_id  recency_score  matches_played  total_runs  total_balls_faced  \
# 0         87163   1.626480e+09               2          24                 23
# 1        150093   1.687150e+09               5          56                 41
# 2        196580   1.684022e+09               5          10                 13
# 3        210328   1.682709e+09               5          61                 49
# 4        211658   1.636200e+09               4         140                145
# ..          ...            ...             ...         ...                ...
# 191     9103996   1.672358e+09               3          17                 27
# 192     9227455   1.673741e+09               2          17                 25
# 193     9245319   1.697962e+09               3          14                 13
# 194     9346861   1.676045e+09               3          45                 45
# 195     9822259   1.697933e+09               2          52                 23
#
#       recent_sr
# 0    104.347826
# 1    136.585366
# 2     76.923077
# 3    124.489796
# 4     96.551724
# ..          ...
# 191   62.962963
# 192   68.000000
# 193  107.692308
# 194  100.000000
# 195  226.086957
#
# [196 rows x 6 columns]
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])

# %%
c_and_r_wk  =pd.merge(consistency_df_wk, recency_df_wk, on ='batsman_id')
c_and_r_wk
# Out:
#      batsman_id  std_strike_rate  recency_score  matches_played  total_runs  \
# 0         87163        58.138320   1.626480e+09               2          24
# 1        150093        98.718005   1.687150e+09               5          56
# 2        196580        95.421785   1.684022e+09               5          10
# 3        210328        92.617033   1.682709e+09               5          61
# 4        211658        29.569459   1.636200e+09               4         140
# ..          ...              ...            ...             ...         ...
# 191     9103996        34.691765   1.672358e+09               3          17
# 192     9227455        20.279822   1.673741e+09               2          17
# 193     9245319        55.075705   1.697962e+09               3          14
# 194     9346861        45.661042   1.676045e+09               3          45
# 195     9822259        20.202041   1.697933e+09               2          52
#
#      total_balls_faced   recent_sr
# 0                   23  104.347826
# 1                   41  136.585366
# 2                   13   76.923077
# 3                   49  124.489796
# 4                  145   96.551724
# ..                 ...         ...
# 191                 27   62.962963
# 192                 25   68.000000
# 193                 13  107.692308
# 194                 45  100.000000
# 195                 23  226.086957
#
# [196 rows x 7 columns]

# %%
final_wk  =pd.merge(c_and_r_wk, wk_stats, on ='batsman_id')
final_wk
# Out:
#      batsman_id  std_strike_rate  recency_score  matches_played  total_runs  \
# 0         87163        58.138320   1.626480e+09               2          24
# 1        150093        98.718005   1.687150e+09               5          56
# 2        196580        95.421785   1.684022e+09               5          10
# 3        210328        92.617033   1.682709e+09               5          61
# 4        211658        29.569459   1.636200e+09               4         140
# ..          ...              ...            ...             ...         ...
# 191     9103996        34.691765   1.672358e+09               3          17
# 192     9227455        20.279822   1.673741e+09               2          17
# 193     9245319        55.075705   1.697962e+09               3          14
# 194     9346861        45.661042   1.676045e+09               3          45
# 195     9822259        20.202041   1.697933e+09               2          52
#
#      total_balls_faced   recent_sr  cumulative_runs  half_centuries  \
# 0                   23  104.347826               24               0
# 1                   41  136.585366              506               2
# 2                   13   76.923077              338               1
# 3                   49  124.489796              980               2
# 4                  145   96.551724              140               1
# ..                 ...         ...              ...             ...
# 191                 27   62.962963               17               0
# 192                 25   68.000000               17               0
# 193                 13  107.692308               14               0
# 194                 45  100.000000               45               0
# 195                 23  226.086957               52               0
#
#      centuries  matches  strike_rate  is_batsman_keeper    average  \
# 0            0        2    81.110000                  2  12.000000
# 1            0       39   115.135128                 39  12.974359
# 2            0       27   126.612593                 27  12.518519
# 3            0       59   137.973559                 48  16.610169
# 4            0        4    84.737500                  4  35.000000
# ..         ...      ...          ...                ...        ...
# 191          0        3    44.443333                  3   5.666667
# 192          0        2    73.160000                  2   8.500000
# 193          0        3   103.333333                  2   4.666667
# 194          0        3    97.060000                  3  15.000000
# 195          0        2   214.285000                  2  26.000000
#
#      score_strike  score_half_centuries  score_centuries  score_average  \
# 0              30                     0                0              5
# 1              40                     5                0              5
# 2              40                     5                0              5
# 3              40                     5                0              5
# 4              30                     5                0             10
# ..            ...                   ...              ...            ...
# 191             0                     0                0              5
# 192             0                     0                0              5
# 193            40                     0                0              5
# 194            30                     0                0              5
# 195            50                     0                0              5
#
#      total_score
# 0             35
# 1             50
# 2             50
# 3             50
# 4             45
# ..           ...
# 191            5
# 192            5
# 193           45
# 194           35
# 195           55
#
# [196 rows x 19 columns]

# %%
low = final_wk['recency_score'].max()
high = final_wk['recency_score'].min()
mid = (low+high)/2
final_wk2 = final_wk[final_wk['recency_score']>mid]

# %%
# Adding normalised columns
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
final_wk2['total_score_normalised'] = scaler.fit_transform(final_wk2[['total_score']])
final_wk2['std_sr_normalised'] = scaler.fit_transform(-final_wk2[['std_strike_rate']])
final_wk2['recent_sr_normalised'] = scaler.fit_transform(final_wk2[['recent_sr']])
final_wk2['recent_matches_played'] = scaler.fit_transform(final_wk2[['matches_played']])
final_wk2['sum'] = final_wk2['std_sr_normalised'] + final_wk2['recent_sr_normalised'] + final_wk2['total_score_normalised'] + final_wk2['recent_matches_played']
final_wk2
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3885437773.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_wk2['total_score_normalised'] = scaler.fit_transform(final_wk2[['total_score']])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3885437773.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_wk2['std_sr_normalised'] = scaler.fit_transform(-final_wk2[['std_strike_rate']])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3885437773.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_wk2['recent_sr_normalised'] = scaler.fit_transform(final_wk2[['recent_sr']])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3885437773.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_wk2['recent_matches_played'] = scaler.fit_transform(final_wk2[['matches_played']])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3885437773.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_wk2['sum'] = final_wk2['std_sr_normalised'] + final_wk2['recent_sr_normalised'] + final_wk2['total_score_normalised'] + final_wk2['recent_matches_played']
#      batsman_id  std_strike_rate  recency_score  matches_played  total_runs  \
# 1        150093        98.718005   1.687150e+09               5          56
# 2        196580        95.421785   1.684022e+09               5          10
# 3        210328        92.617033   1.682709e+09               5          61
# 8        363047        61.083692   1.693475e+09               5         106
# 10       392216        57.542840   1.676056e+09               5         203
# ..          ...              ...            ...             ...         ...
# 191     9103996        34.691765   1.672358e+09               3          17
# 192     9227455        20.279822   1.673741e+09               2          17
# 193     9245319        55.075705   1.697962e+09               3          14
# 194     9346861        45.661042   1.676045e+09               3          45
# 195     9822259        20.202041   1.697933e+09               2          52
#
#      total_balls_faced   recent_sr  cumulative_runs  half_centuries  \
# 1                   41  136.585366              506               2
# 2                   13   76.923077              338               1
# 3                   49  124.489796              980               2
# 8                   77  137.662338             1436               8
# 10                 145  140.000000              688               4
# ..                 ...         ...              ...             ...
# 191                 27   62.962963               17               0
# 192                 25   68.000000               17               0
# 193                 13  107.692308               14               0
# 194                 45  100.000000               45               0
# 195                 23  226.086957               52               0
#
#      centuries  matches  strike_rate  is_batsman_keeper    average  \
# 1            0       39   115.135128                 39  12.974359
# 2            0       27   126.612593                 27  12.518519
# 3            0       59   137.973559                 48  16.610169
# 8            2       57   112.297368                 27  25.192982
# 10           0       33    94.050303                 20  20.848485
# ..         ...      ...          ...                ...        ...
# 191          0        3    44.443333                  3   5.666667
# 192          0        2    73.160000                  2   8.500000
# 193          0        3   103.333333                  2   4.666667
# 194          0        3    97.060000                  3  15.000000
# 195          0        2   214.285000                  2  26.000000
#
#      score_strike  score_half_centuries  score_centuries  score_average  \
# 1              40                     5                0              5
# 2              40                     5                0              5
# 3              40                     5                0              5
# 8              40                    20               20              5
# 10             30                    10                0              5
# ..            ...                   ...              ...            ...
# 191             0                     0                0              5
# 192             0                     0                0              5
# 193            40                     0                0              5
# 194            30                     0                0              5
# 195            50                     0                0              5
#
#      total_score  total_score_normalised  std_sr_normalised  \
# 1             50                0.473684           0.000000
# 2             50                0.473684           0.037374
# 3             50                0.473684           0.069175
# 8             85                0.842105           0.426711
# 10            45                0.421053           0.466858
# ..           ...                     ...                ...
# 191            5                0.000000           0.725952
# 192            5                0.000000           0.889360
# 193           45                0.421053           0.494832
# 194           35                0.315789           0.601578
# 195           55                0.526316           0.890241
#
#      recent_sr_normalised  recent_matches_played       sum
# 1                0.511534               1.000000  1.985218
# 2                0.185919               1.000000  1.696977
# 3                0.445521               1.000000  1.988380
# 8                0.517411               1.000000  2.786228
# 10               0.530169               1.000000  2.418081
# ..                    ...                    ...       ...
# 191              0.109730               0.333333  1.169015
# 192              0.137220               0.000000  1.026580
# 193              0.353846               0.333333  1.603064
# 194              0.311864               0.333333  1.562566
# 195              1.000000               0.000000  2.416557
#
# [142 rows x 24 columns]

# %%
final_sorted_wk = final_wk2.sort_values(by=['sum'], ascending=[False])
final_sorted_wk.head()
# Out:
#      batsman_id  std_strike_rate  recency_score  matches_played  total_runs  \
# 31      2263736        43.395586   1.680670e+09               5         179
# 29      2162782        58.786308   1.697103e+09               5         233
# 108     4685568        60.998638   1.696861e+09               5         249
# 100     4230127        68.570623   1.697708e+09               5         220
# 92      4069666        46.989264   1.698227e+09               5         259
#
#      total_balls_faced   recent_sr  cumulative_runs  half_centuries  \
# 31                 134  133.582090             4031              40
# 29                 149  156.375839             3498              32
# 108                122  204.098361             2525              15
# 100                120  183.333333             2176              11
# 92                 165  156.969697              873               4
#
#      centuries  matches  strike_rate  is_batsman_keeper    average  \
# 31           2       92   115.673261                 84  43.815217
# 29           6       97   123.307835                 61  36.061856
# 108          1      105   132.002952                 63  24.047619
# 100          1      101   120.201287                 58  21.544554
# 92           1       32   118.593437                 12  27.281250
#
#      score_strike  score_half_centuries  score_centuries  score_average  \
# 31             40                    20               20             20
# 29             40                    20               30             10
# 108            40                    20               10              5
# 100            40                    20               10              5
# 92             40                    10               10              5
#
#      total_score  total_score_normalised  std_sr_normalised  \
# 31           100                1.000000           0.627265
# 29           100                1.000000           0.452760
# 108           75                0.736842           0.427675
# 100           75                0.736842           0.341822
# 92            65                0.631579           0.586519
#
#      recent_sr_normalised  recent_matches_played       sum
# 31               0.495143                    1.0  3.122408
# 29               0.619543                    1.0  3.072302
# 108              0.879994                    1.0  3.044512
# 100              0.766667                    1.0  2.845330
# 92               0.622784                    1.0  2.840881

# %%
# comparing with near best 11 provided
wk_best11_df =pd.merge(final_sorted_wk, nearbest_11, left_on='batsman_id', right_on='Player_id', how='inner')
wk_best11_df
# Out:
#    batsman_id  std_strike_rate  recency_score  matches_played  total_runs  \
# 0     8250115        44.223173   1.699799e+09               5         160
#
#    total_balls_faced   recent_sr  cumulative_runs  half_centuries  centuries  \
# 0                152  105.263158              700               6          0
#
#    matches  strike_rate  is_batsman_keeper    average  score_strike  \
# 0       21   100.807619                 13  33.333333            40
#
#    score_half_centuries  score_centuries  score_average  total_score  \
# 0                    20                0             10           70
#
#    total_score_normalised  std_sr_normalised  recent_sr_normalised  \
# 0                0.684211           0.617881              0.340589
#
#    recent_matches_played       sum  Player_id
# 0                    1.0  2.642681    8250115

# %% [markdown]
# # ALL ROUNDER SELECTION

# %%
selected_allround_from_bat = batsman_stats[batsman_stats['cumulative_runs'] > 10]
selected_allround_from_bowl = bowler_stats[bowler_stats['cumulative_wickets'] >= 1]
selected_allround_from_bowl2 = selected_allround_from_bowl[selected_allround_from_bowl['matches'] >= 2]
  

allround_df =pd.merge(selected_allround_from_bat, selected_allround_from_bowl2, left_on='batsman_id', right_on='bowler_id', how='inner')
allround_df['total_score_allround'] = allround_df['total_score'] + allround_df['total_score_bowl']
allround_df
# Out:
#      batsman_id  cumulative_runs  half_centuries  centuries  matches_x  \
# 0         34061              729               2          0         52
# 1         41740              976               6          0         41
# 2         49496               23               0          0          5
# 3         55299               20               0          0          6
# 4         62432             1911               7          0         87
# ..          ...              ...             ...        ...        ...
# 789     9266102               27               0          0          2
# 790     9307892               11               0          0          3
# 791     9329494               13               0          0          1
# 792     9346854               63               0          0          3
# 793     9413816               12               0          0          2
#
#      strike_rate    average  score_strike  score_half_centuries  \
# 0     119.160577  14.019231            40                     5
# 1     116.654878  23.804878            40                    20
# 2     106.192000   4.600000            40                     0
# 3      79.166667   3.333333             0                     0
# 4     121.130345  21.965517            40                    20
# ..           ...        ...           ...                   ...
# 789    97.180000  13.500000            30                     0
# 790    66.346667   3.666667             0                     0
# 791    92.860000  13.000000            30                     0
# 792   144.973333  21.000000            40                     0
# 793   120.000000   6.000000            40                     0
#
#      score_centuries  score_average  total_score  bowler_id  \
# 0                  0              5           50      34061
# 1                  0              5           65      41740
# 2                  0              5           45      49496
# 3                  0              5            5      55299
# 4                  0              5           65      62432
# ..               ...            ...          ...        ...
# 789                0              5           35    9266102
# 790                0              5            5    9307892
# 791                0              5           35    9329494
# 792                0              5           45    9346854
# 793                0              5           45    9413816
#
#      cumulative_wickets  balls_bowled  runs_given  count_4w_per_inning  \
# 0                    27           635         965                    0
# 1                     5            90          76                    0
# 2                    31           516         533                    0
# 3                    46           709         978                    0
# 4                    72          1178        1418                    0
# ..                  ...           ...         ...                  ...
# 789                   2            48          44                    0
# 790                   6           114         163                    0
# 791                   2            24          26                    0
# 792                   2            52          77                    0
# 793                   2            48          39                    0
#
#      matches_y   economy  strike_rate_bowl  average_bowl  score_strike_bowl  \
# 0           46  9.490000         23.518519     35.740741                 10
# 1           10  5.900000         18.000000     15.200000                 20
# 2           23  6.203043         16.645161     17.193548                 20
# 3           35  8.097429         15.413043     21.260870                 20
# 4           77  7.826494         16.361111     19.694444                 20
# ..         ...       ...               ...           ...                ...
# 789          3  5.333333         24.000000     22.000000                 10
# 790          7  9.392857         19.000000     27.166667                 20
# 791          2  9.335000         12.000000     13.000000                 30
# 792          3  8.416667         26.000000     38.500000                  0
# 793          2  4.875000         24.000000     19.500000                 10
#
#      score_economy  score_average_bowl  score_4w  total_score_bowl  \
# 0                0                  10         0                20
# 1               30                  30         0                80
# 2               30                  30         0                80
# 3                0                  20         0                40
# 4                0                  30         0                50
# ..             ...                 ...       ...               ...
# 789             30                  20         0                60
# 790              0                  20         0                40
# 791              0                  30         0                60
# 792              0                  10         0                10
# 793             40                  30         0                80
#
#      total_score_allround
# 0                      70
# 1                     145
# 2                     125
# 3                      45
# 4                     115
# ..                    ...
# 789                    95
# 790                    45
# 791                    95
# 792                    55
# 793                   125
#
# [794 rows x 27 columns]

# %%
# calculate consistency
consistency_df_allrounder = calculate_consistency_for_all_batsman(batsman_df, allround_df)
print(consistency_df_allrounder)
# Out:
#      batsman_id  std_strike_rate
# 0         34061        87.348364
# 1         41740        53.823271
# 2         49496        76.849510
# 3         55299       101.070383
# 4         62432        62.318474
# ..          ...              ...
# 789     9266102        14.863385
# 790     9307892        28.735453
# 791     9329494              NaN
# 792     9346854        26.898605
# 793     9413816       169.705627
#
# [794 rows x 2 columns]

# %%
consistency_df_allrounder2 = calculate_consistency_for_all_bowlers(bowler_df,allround_df)
print(consistency_df_allrounder2)
# Out:
#      bowler_id  std_economy  std_bowler_strike_rate
# 0        34061     3.286222                4.904080
# 1        41740     1.527525                1.154701
# 2        49496     1.922590                8.389912
# 3        55299     2.393895                6.964613
# 4        62432     4.116509                6.374948
# ..         ...          ...                     ...
# 789    9266102     0.473762                4.242641
# 790    9307892     4.740671                8.246211
# 791    9329494          NaN                     NaN
# 792    9346854     3.358757                8.485281
# 793    9413816          NaN                     NaN
#
# [794 rows x 3 columns]

# %%
# calculate rcency
recency_df_allrounder = calculate_recency_for_all_batsman(batsman_df, allround_df)
print(recency_df_allrounder)
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\3194042368.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_df['match_dt'] = pd.to_datetime(batsman_df['match_dt'])

# %%
recency_df_allrounder2 = calculate_recency_for_all_bowlers(bowler_df,allround_df)
print(recency_df_allrounder2)
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\553790713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bowler_df['match_dt'] = pd.to_datetime(bowler_df['match_dt'])

# %%
c_allrounder  =pd.merge(consistency_df_allrounder, consistency_df_allrounder2, left_on ='batsman_id', right_on='bowler_id')
c_allrounder
# Out:
#      batsman_id  std_strike_rate  bowler_id  std_economy  \
# 0         34061        87.348364      34061     3.286222
# 1         41740        53.823271      41740     1.527525
# 2         49496        76.849510      49496     1.922590
# 3         55299       101.070383      55299     2.393895
# 4         62432        62.318474      62432     4.116509
# ..          ...              ...        ...          ...
# 789     9266102        14.863385    9266102     0.473762
# 790     9307892        28.735453    9307892     4.740671
# 791     9329494              NaN    9329494          NaN
# 792     9346854        26.898605    9346854     3.358757
# 793     9413816       169.705627    9413816          NaN
#
#      std_bowler_strike_rate
# 0                  4.904080
# 1                  1.154701
# 2                  8.389912
# 3                  6.964613
# 4                  6.374948
# ..                      ...
# 789                4.242641
# 790                8.246211
# 791                     NaN
# 792                8.485281
# 793                     NaN
#
# [794 rows x 5 columns]

# %%
r_allrounder  =pd.merge(recency_df_allrounder, recency_df_allrounder2, left_on ='batsman_id', right_on='bowler_id')
r_allrounder
# Out:
#      batsman_id  recency_score_x  matches_played_x  total_runs  \
# 0         34061     1.673914e+09                 5          38
# 1         41740     1.680376e+09                 5         116
# 2         49496     1.635967e+09                 5          23
# 3         55299     1.661731e+09                 5          20
# 4         62432     1.695082e+09                 5         115
# ..          ...              ...               ...         ...
# 789     9266102     1.663675e+09                 2          27
# 790     9307892     1.683907e+09                 3          11
# 791     9329494     1.696550e+09                 1          13
# 792     9346854     1.676045e+09                 3          63
# 793     9413816     1.696982e+09                 2          12
#
#      total_balls_faced   recent_sr  bowler_id  recency_score_y  \
# 0                   32  118.750000      34061     1.669075e+09
# 1                  102  113.725490      41740     1.651847e+09
# 2                   24   95.833333      49496     1.680376e+09
# 3                   20  100.000000      55299     1.692714e+09
# 4                   80  143.750000      62432     1.697034e+09
# ..                 ...         ...        ...              ...
# 789                 28   96.428571    9266102     1.673654e+09
# 790                 15   73.333333    9307892     1.685146e+09
# 791                 14   92.857143    9329494     1.696594e+09
# 792                 44  143.181818    9346854     1.676045e+09
# 793                  6  200.000000    9413816     1.696982e+09
#
#      matches_played_y  total_wickets  total_runs_conceded  \
# 0                   5              2                   73
# 1                   5              1                   35
# 2                   5              8                  119
# 3                   5              3                  150
# 4                   5              2                   90
# ..                ...            ...                  ...
# 789                 3              2                   44
# 790                 5              5                  113
# 791                 2              2                   26
# 792                 3              2                   77
# 793                 2              2                   39
#
#      average_runs_conceded
# 0                   36.500
# 1                   35.000
# 2                   14.875
# 3                   50.000
# 4                   45.000
# ..                     ...
# 789                 22.000
# 790                 22.600
# 791                 13.000
# 792                 38.500
# 793                 19.500
#
# [794 rows x 12 columns]

# %%
c_and_r_allrounder  =pd.merge(c_allrounder, r_allrounder, on ='batsman_id')
c_and_r_allrounder
# Out:
#      batsman_id  std_strike_rate  bowler_id_x  std_economy  \
# 0         34061        87.348364        34061     3.286222
# 1         41740        53.823271        41740     1.527525
# 2         49496        76.849510        49496     1.922590
# 3         55299       101.070383        55299     2.393895
# 4         62432        62.318474        62432     4.116509
# ..          ...              ...          ...          ...
# 789     9266102        14.863385      9266102     0.473762
# 790     9307892        28.735453      9307892     4.740671
# 791     9329494              NaN      9329494          NaN
# 792     9346854        26.898605      9346854     3.358757
# 793     9413816       169.705627      9413816          NaN
#
#      std_bowler_strike_rate  recency_score_x  matches_played_x  total_runs  \
# 0                  4.904080     1.673914e+09                 5          38
# 1                  1.154701     1.680376e+09                 5         116
# 2                  8.389912     1.635967e+09                 5          23
# 3                  6.964613     1.661731e+09                 5          20
# 4                  6.374948     1.695082e+09                 5         115
# ..                      ...              ...               ...         ...
# 789                4.242641     1.663675e+09                 2          27
# 790                8.246211     1.683907e+09                 3          11
# 791                     NaN     1.696550e+09                 1          13
# 792                8.485281     1.676045e+09                 3          63
# 793                     NaN     1.696982e+09                 2          12
#
#      total_balls_faced   recent_sr  bowler_id_y  recency_score_y  \
# 0                   32  118.750000        34061     1.669075e+09
# 1                  102  113.725490        41740     1.651847e+09
# 2                   24   95.833333        49496     1.680376e+09
# 3                   20  100.000000        55299     1.692714e+09
# 4                   80  143.750000        62432     1.697034e+09
# ..                 ...         ...          ...              ...
# 789                 28   96.428571      9266102     1.673654e+09
# 790                 15   73.333333      9307892     1.685146e+09
# 791                 14   92.857143      9329494     1.696594e+09
# 792                 44  143.181818      9346854     1.676045e+09
# 793                  6  200.000000      9413816     1.696982e+09
#
#      matches_played_y  total_wickets  total_runs_conceded  \
# 0                   5              2                   73
# 1                   5              1                   35
# 2                   5              8                  119
# 3                   5              3                  150
# 4                   5              2                   90
# ..                ...            ...                  ...
# 789                 3              2                   44
# 790                 5              5                  113
# 791                 2              2                   26
# 792                 3              2                   77
# 793                 2              2                   39
#
#      average_runs_conceded
# 0                   36.500
# 1                   35.000
# 2                   14.875
# 3                   50.000
# 4                   45.000
# ..                     ...
# 789                 22.000
# 790                 22.600
# 791                 13.000
# 792                 38.500
# 793                 19.500
#
# [794 rows x 16 columns]

# %%
final_allrounder  =pd.merge(c_and_r_allrounder, allround_df, on ='batsman_id')
final_allrounder
# Out:
#      batsman_id  std_strike_rate  bowler_id_x  std_economy  \
# 0         34061        87.348364        34061     3.286222
# 1         41740        53.823271        41740     1.527525
# 2         49496        76.849510        49496     1.922590
# 3         55299       101.070383        55299     2.393895
# 4         62432        62.318474        62432     4.116509
# ..          ...              ...          ...          ...
# 789     9266102        14.863385      9266102     0.473762
# 790     9307892        28.735453      9307892     4.740671
# 791     9329494              NaN      9329494          NaN
# 792     9346854        26.898605      9346854     3.358757
# 793     9413816       169.705627      9413816          NaN
#
#      std_bowler_strike_rate  recency_score_x  matches_played_x  total_runs  \
# 0                  4.904080     1.673914e+09                 5          38
# 1                  1.154701     1.680376e+09                 5         116
# 2                  8.389912     1.635967e+09                 5          23
# 3                  6.964613     1.661731e+09                 5          20
# 4                  6.374948     1.695082e+09                 5         115
# ..                      ...              ...               ...         ...
# 789                4.242641     1.663675e+09                 2          27
# 790                8.246211     1.683907e+09                 3          11
# 791                     NaN     1.696550e+09                 1          13
# 792                8.485281     1.676045e+09                 3          63
# 793                     NaN     1.696982e+09                 2          12
#
#      total_balls_faced   recent_sr  bowler_id_y  recency_score_y  \
# 0                   32  118.750000        34061     1.669075e+09
# 1                  102  113.725490        41740     1.651847e+09
# 2                   24   95.833333        49496     1.680376e+09
# 3                   20  100.000000        55299     1.692714e+09
# 4                   80  143.750000        62432     1.697034e+09
# ..                 ...         ...          ...              ...
# 789                 28   96.428571      9266102     1.673654e+09
# 790                 15   73.333333      9307892     1.685146e+09
# 791                 14   92.857143      9329494     1.696594e+09
# 792                 44  143.181818      9346854     1.676045e+09
# 793                  6  200.000000      9413816     1.696982e+09
#
#      matches_played_y  total_wickets  total_runs_conceded  \
# 0                   5              2                   73
# 1                   5              1                   35
# 2                   5              8                  119
# 3                   5              3                  150
# 4                   5              2                   90
# ..                ...            ...                  ...
# 789                 3              2                   44
# 790                 5              5                  113
# 791                 2              2                   26
# 792                 3              2                   77
# 793                 2              2                   39
#
#      average_runs_conceded  cumulative_runs  half_centuries  centuries  \
# 0                   36.500              729               2          0
# 1                   35.000              976               6          0
# 2                   14.875               23               0          0
# 3                   50.000               20               0          0
# 4                   45.000             1911               7          0
# ..                     ...              ...             ...        ...
# 789                 22.000               27               0          0
# 790                 22.600               11               0          0
# 791                 13.000               13               0          0
# 792                 38.500               63               0          0
# 793                 19.500               12               0          0
#
#      matches_x  strike_rate    average  score_strike  score_half_centuries  \
# 0           52   119.160577  14.019231            40                     5
# 1           41   116.654878  23.804878            40                    20
# 2            5   106.192000   4.600000            40                     0
# 3            6    79.166667   3.333333             0                     0
# 4           87   121.130345  21.965517            40                    20
# ..         ...          ...        ...           ...                   ...
# 789          2    97.180000  13.500000            30                     0
# 790          3    66.346667   3.666667             0                     0
# 791          1    92.860000  13.000000            30                     0
# 792          3   144.973333  21.000000            40                     0
# 793          2   120.000000   6.000000            40                     0
#
#      score_centuries  score_average  total_score  bowler_id  \
# 0                  0              5           50      34061
# 1                  0              5           65      41740
# 2                  0              5           45      49496
# 3                  0              5            5      55299
# 4                  0              5           65      62432
# ..               ...            ...          ...        ...
# 789                0              5           35    9266102
# 790                0              5            5    9307892
# 791                0              5           35    9329494
# 792                0              5           45    9346854
# 793                0              5           45    9413816
#
#      cumulative_wickets  balls_bowled  runs_given  count_4w_per_inning  \
# 0                    27           635         965                    0
# 1                     5            90          76                    0
# 2                    31           516         533                    0
# 3                    46           709         978                    0
# 4                    72          1178        1418                    0
# ..                  ...           ...         ...                  ...
# 789                   2            48          44                    0
# 790                   6           114         163                    0
# 791                   2            24          26                    0
# 792                   2            52          77                    0
# 793                   2            48          39                    0
#
#      matches_y   economy  strike_rate_bowl  average_bowl  score_strike_bowl  \
# 0           46  9.490000         23.518519     35.740741                 10
# 1           10  5.900000         18.000000     15.200000                 20
# 2           23  6.203043         16.645161     17.193548                 20
# 3           35  8.097429         15.413043     21.260870                 20
# 4           77  7.826494         16.361111     19.694444                 20
# ..         ...       ...               ...           ...                ...
# 789          3  5.333333         24.000000     22.000000                 10
# 790          7  9.392857         19.000000     27.166667                 20
# 791          2  9.335000         12.000000     13.000000                 30
# 792          3  8.416667         26.000000     38.500000                  0
# 793          2  4.875000         24.000000     19.500000                 10
#
#      score_economy  score_average_bowl  score_4w  total_score_bowl  \
# 0                0                  10         0                20
# 1               30                  30         0                80
# 2               30                  30         0                80
# 3                0                  20         0                40
# 4                0                  30         0                50
# ..             ...                 ...       ...               ...
# 789             30                  20         0                60
# 790              0                  20         0                40
# 791              0                  30         0                60
# 792              0                  10         0                10
# 793             40                  30         0                80
#
#      total_score_allround
# 0                      70
# 1                     145
# 2                     125
# 3                      45
# 4                     115
# ..                    ...
# 789                    95
# 790                    45
# 791                    95
# 792                    55
# 793                   125
#
# [794 rows x 42 columns]

# %%
low = final_allrounder['recency_score_x'].max()
high = final_allrounder['recency_score_x'].min()
mid = (low+high)/2
final_allrounder2 = final_allrounder[final_allrounder['recency_score_x']>mid]

# %%
low = final_allrounder2['recency_score_y'].max()
high = final_allrounder2['recency_score_y'].min()
mid = (low+high)/2
final_allrounder3 = final_allrounder2[final_allrounder2['recency_score_y']>mid]

# %%
# Adding normalised columns
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
final_allrounder3['total_score_normalised'] = scaler.fit_transform(final_allrounder3[['total_score_allround']])
final_allrounder3['std_sr_normalised'] = scaler.fit_transform(-final_allrounder3[['std_strike_rate']])
final_allrounder3['recent_sr_normalised'] = scaler.fit_transform(final_allrounder3[['recent_sr']])
final_allrounder3['recent_matches_batsman'] = scaler.fit_transform(final_allrounder3[['matches_played_x']])
final_allrounder3['recent_matches_bowler'] = scaler.fit_transform(final_allrounder3[['matches_played_y']])
final_allrounder3['std_bowler_economy_normalised'] = scaler.fit_transform(-final_allrounder3[['std_economy']])
final_allrounder3['recent_average_normalised'] = scaler.fit_transform(-final_allrounder3[['average_runs_conceded']])
final_allrounder3['sum'] = final_allrounder3['std_sr_normalised'] + final_allrounder3['recent_sr_normalised'] + final_allrounder3['total_score_normalised']+final_allrounder3['std_bowler_economy_normalised']+final_allrounder3['recent_average_normalised'] + final_allrounder3['recent_matches_batsman'] + final_allrounder3['recent_matches_bowler']
final_allrounder3
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\93044396.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_allrounder3['total_score_normalised'] = scaler.fit_transform(final_allrounder3[['total_score_allround']])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\93044396.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_allrounder3['std_sr_normalised'] = scaler.fit_transform(-final_allrounder3[['std_strike_rate']])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\93044396.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_allrounder3['recent_sr_normalised'] = scaler.fit_transform(final_allrounder3[['recent_sr']])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\93044396.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_allrounder3['recent_matches_batsman'] = scaler.fit_transform(final_allrounder3[['matches_played_x']])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\93044396.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_allrounder3['recent_matches_bowler'] = scaler.fit_transform(final_allrounder3[['matches_played_y']])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\93044396.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_allrounder3['std_bowler_economy_normalised'] = scaler.fit_transform(-final_allrounder3[['std_economy']])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\93044396.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_allrounder3['recent_average_normalised'] = scaler.fit_transform(-final_allrounder3[['average_runs_conceded']])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\93044396.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_allrounder3['sum'] = final_allrounder3['std_sr_normalised'] + final_allrounder3['recent_sr_normalised'] + final_allrounder3['total_score_normalised']+final_allrounder3['std_bowler_economy_normalised']+final_allrounder3['recent_average_normalised'] + final_allrounder3['recent_matches_batsman'] + final_allrounder3['recent_matches_bowler']
#      batsman_id  std_strike_rate  bowler_id_x  std_economy  \
# 0         34061        87.348364        34061     3.286222
# 3         55299       101.070383        55299     2.393895
# 4         62432        62.318474        62432     4.116509
# 6         74087        56.746410        74087     1.891041
# 9         87191        58.744637        87191     1.879594
# ..          ...              ...          ...          ...
# 789     9266102        14.863385      9266102     0.473762
# 790     9307892        28.735453      9307892     4.740671
# 791     9329494              NaN      9329494          NaN
# 792     9346854        26.898605      9346854     3.358757
# 793     9413816       169.705627      9413816          NaN
#
#      std_bowler_strike_rate  recency_score_x  matches_played_x  total_runs  \
# 0                  4.904080     1.673914e+09                 5          38
# 3                  6.964613     1.661731e+09                 5          20
# 4                  6.374948     1.695082e+09                 5         115
# 6                  6.192313     1.689068e+09                 5          79
# 9                  6.236096     1.687185e+09                 5         190
# ..                      ...              ...               ...         ...
# 789                4.242641     1.663675e+09                 2          27
# 790                8.246211     1.683907e+09                 3          11
# 791                     NaN     1.696550e+09                 1          13
# 792                8.485281     1.676045e+09                 3          63
# 793                     NaN     1.696982e+09                 2          12
#
#      total_balls_faced   recent_sr  bowler_id_y  recency_score_y  \
# 0                   32  118.750000        34061     1.669075e+09
# 3                   20  100.000000        55299     1.692714e+09
# 4                   80  143.750000        62432     1.697034e+09
# 6                   74  106.756757        74087     1.689863e+09
# 9                  106  179.245283        87191     1.686493e+09
# ..                 ...         ...          ...              ...
# 789                 28   96.428571      9266102     1.673654e+09
# 790                 15   73.333333      9307892     1.685146e+09
# 791                 14   92.857143      9329494     1.696594e+09
# 792                 44  143.181818      9346854     1.676045e+09
# 793                  6  200.000000      9413816     1.696982e+09
#
#      matches_played_y  total_wickets  total_runs_conceded  \
# 0                   5              2                   73
# 3                   5              3                  150
# 4                   5              2                   90
# 6                   5              7                   99
# 9                   5              1                   64
# ..                ...            ...                  ...
# 789                 3              2                   44
# 790                 5              5                  113
# 791                 2              2                   26
# 792                 3              2                   77
# 793                 2              2                   39
#
#      average_runs_conceded  cumulative_runs  half_centuries  centuries  \
# 0                36.500000              729               2          0
# 3                50.000000               20               0          0
# 4                45.000000             1911               7          0
# 6                14.142857             1338              10          0
# 9                64.000000             1127               4          0
# ..                     ...              ...             ...        ...
# 789              22.000000               27               0          0
# 790              22.600000               11               0          0
# 791              13.000000               13               0          0
# 792              38.500000               63               0          0
# 793              19.500000               12               0          0
#
#      matches_x  strike_rate    average  score_strike  score_half_centuries  \
# 0           52   119.160577  14.019231            40                     5
# 3            6    79.166667   3.333333             0                     0
# 4           87   121.130345  21.965517            40                    20
# 6           65   103.259385  20.584615            40                    20
# 9           52    98.856538  21.673077            30                    10
# ..         ...          ...        ...           ...                   ...
# 789          2    97.180000  13.500000            30                     0
# 790          3    66.346667   3.666667             0                     0
# 791          1    92.860000  13.000000            30                     0
# 792          3   144.973333  21.000000            40                     0
# 793          2   120.000000   6.000000            40                     0
#
#      score_centuries  score_average  total_score  bowler_id  \
# 0                  0              5           50      34061
# 3                  0              5            5      55299
# 4                  0              5           65      62432
# 6                  0              5           65      74087
# 9                  0              5           45      87191
# ..               ...            ...          ...        ...
# 789                0              5           35    9266102
# 790                0              5            5    9307892
# 791                0              5           35    9329494
# 792                0              5           45    9346854
# 793                0              5           45    9413816
#
#      cumulative_wickets  balls_bowled  runs_given  count_4w_per_inning  \
# 0                    27           635         965                    0
# 3                    46           709         978                    0
# 4                    72          1178        1418                    0
# 6                    30           609         790                    0
# 9                    13           302         398                    0
# ..                  ...           ...         ...                  ...
# 789                   2            48          44                    0
# 790                   6           114         163                    0
# 791                   2            24          26                    0
# 792                   2            52          77                    0
# 793                   2            48          39                    0
#
#      matches_y   economy  strike_rate_bowl  average_bowl  score_strike_bowl  \
# 0           46  9.490000         23.518519     35.740741                 10
# 3           35  8.097429         15.413043     21.260870                 20
# 4           77  7.826494         16.361111     19.694444                 20
# 6           42  8.110000         20.300000     26.333333                 10
# 9           27  9.134074         23.230769     30.615385                 10
# ..         ...       ...               ...           ...                ...
# 789          3  5.333333         24.000000     22.000000                 10
# 790          7  9.392857         19.000000     27.166667                 20
# 791          2  9.335000         12.000000     13.000000                 30
# 792          3  8.416667         26.000000     38.500000                  0
# 793          2  4.875000         24.000000     19.500000                 10
#
#      score_economy  score_average_bowl  score_4w  total_score_bowl  \
# 0                0                  10         0                20
# 3                0                  20         0                40
# 4                0                  30         0                50
# 6                0                  20         0                30
# 9                0                  10         0                20
# ..             ...                 ...       ...               ...
# 789             30                  20         0                60
# 790              0                  20         0                40
# 791              0                  30         0                60
# 792              0                  10         0                10
# 793             40                  30         0                80
#
#      total_score_allround  total_score_normalised  std_sr_normalised  \
# 0                      70                0.433333           0.661372
# 3                      45                0.266667           0.605407
# 4                     115                0.733333           0.763456
# 6                      95                0.600000           0.786181
# 9                      65                0.400000           0.778032
# ..                    ...                     ...                ...
# 789                    95                0.600000           0.957001
# 790                    45                0.266667           0.900424
# 791                    95                0.600000                NaN
# 792                    55                0.333333           0.907915
# 793                   125                0.800000           0.325479
#
#      recent_sr_normalised  recent_matches_batsman  recent_matches_bowler  \
# 0                0.398148                    1.00               1.000000
# 3                0.325926                    1.00               1.000000
# 4                0.494444                    1.00               1.000000
# 6                0.351952                    1.00               1.000000
# 9                0.631167                    1.00               1.000000
# ..                    ...                     ...                    ...
# 789              0.312169                    0.25               0.333333
# 790              0.223210                    0.50               1.000000
# 791              0.298413                    0.00               0.000000
# 792              0.492256                    0.50               0.333333
# 793              0.711111                    0.25               0.000000
#
#      std_bowler_economy_normalised  recent_average_normalised       sum
# 0                         0.504189                   0.771875  4.768917
# 3                         0.638820                   0.687500  4.524319
# 4                         0.378919                   0.718750  5.088903
# 6                         0.714688                   0.911607  5.364428
# 9                         0.716415                   0.600000  5.125614
# ..                             ...                        ...       ...
# 789                       0.928521                   0.862500  4.243524
# 790                       0.284748                   0.858750  4.033798
# 791                            NaN                   0.918750       NaN
# 792                       0.493245                   0.759375  3.819458
# 793                            NaN                   0.878125       NaN
#
# [471 rows x 50 columns]

# %%
final_sorted_allrounder = final_allrounder3.sort_values(by=['sum'], ascending=[False])
final_sorted_allrounder.head()
# Out:
#      batsman_id  std_strike_rate  bowler_id_x  std_economy  \
# 731     8246440        52.279858      8246440     1.534747
# 308     3633503        41.662773      3633503     1.134196
# 273     3298427        62.424451      3298427     1.555194
# 675     7906968        64.830608      7906968     1.705561
# 438     4739552        87.461390      4739552     2.140649
#
#      std_bowler_strike_rate  recency_score_x  matches_played_x  total_runs  \
# 731                7.970315     1.695324e+09                 5          67
# 308                7.277820     1.692852e+09                 5          95
# 273                5.201398     1.687807e+09                 5          98
# 675                4.516636     1.698175e+09                 5         132
# 438                5.201343     1.693492e+09                 5          80
#
#      total_balls_faced   recent_sr  bowler_id_y  recency_score_y  \
# 731                 57  117.543860      8246440     1.698123e+09
# 308                 99   95.959596      3633503     1.692818e+09
# 273                 68  144.117647      3298427     1.687236e+09
# 675                 96  137.500000      7906968     1.698175e+09
# 438                 35  228.571429      4739552     1.694598e+09
#
#      matches_played_y  total_wickets  total_runs_conceded  \
# 731                 5              9                   97
# 308                 5              8                   93
# 273                 5              4                  103
# 675                 5              8                   99
# 438                 5              5                  113
#
#      average_runs_conceded  cumulative_runs  half_centuries  centuries  \
# 731              10.777778              114               0          0
# 308              11.625000              344               1          1
# 273              25.750000              762               5          0
# 675              12.375000              493               2          0
# 438              22.600000              573               1          0
#
#      matches_x  strike_rate    average  score_strike  score_half_centuries  \
# 731          8   105.867500  14.250000            40                     0
# 308         17   101.850000  20.235294            40                     5
# 273         31   111.541613  24.580645            40                    20
# 675         18   118.297778  27.388889            40                     5
# 438         37   124.874054  15.486486            40                     5
#
#      score_centuries  score_average  total_score  bowler_id  \
# 731                0              5           45    8246440
# 308               10              5           60    3633503
# 273                0              5           65    3298427
# 675                0              5           50    7906968
# 438                0              5           50    4739552
#
#      cumulative_wickets  balls_bowled  runs_given  count_4w_per_inning  \
# 731                  23           247         214                    1
# 308                  11           174         163                    0
# 273                  23           352         399                    0
# 675                  17           264         295                    0
# 438                  63           874        1318                    1
#
#      matches_y   economy  strike_rate_bowl  average_bowl  score_strike_bowl  \
# 731         12  5.320000         10.739130      9.304348                 30
# 308         10  5.841000         15.818182     14.818182                 20
# 273         23  6.833043         15.304348     17.347826                 20
# 675         14  6.536429         15.529412     17.352941                 20
# 438         49  9.219796         13.873016     20.920635                 30
#
#      score_economy  score_average_bowl  score_4w  total_score_bowl  \
# 731             30                  30        10               100
# 308             30                  30         0                80
# 273             30                  30         0                80
# 675             30                  30         0                80
# 438              0                  20        10                60
#
#      total_score_allround  total_score_normalised  std_sr_normalised  \
# 731                   145                0.933333           0.804398
# 308                   140                0.900000           0.847700
# 273                   145                0.933333           0.763023
# 675                   130                0.833333           0.753210
# 438                   110                0.700000           0.660911
#
#      recent_sr_normalised  recent_matches_batsman  recent_matches_bowler  \
# 731              0.393502                     1.0                    1.0
# 308              0.310363                     1.0                    1.0
# 273              0.495861                     1.0                    1.0
# 675              0.470370                     1.0                    1.0
# 438              0.821164                     1.0                    1.0
#
#      std_bowler_economy_normalised  recent_average_normalised       sum
# 731                       0.768444                   0.932639  5.832317
# 308                       0.828877                   0.927344  5.814284
# 273                       0.765359                   0.839063  5.796639
# 675                       0.742672                   0.922656  5.722242
# 438                       0.677028                   0.858750  5.717853

# %%
# comparing with near best 11 provided
allrounder_best11_df =pd.merge(final_sorted_allrounder, nearbest_11, left_on='batsman_id', right_on='Player_id', how='inner')
allrounder_best11_df
# Out:
#    batsman_id  std_strike_rate  bowler_id_x  std_economy  \
# 0     4171460        43.931313      4171460     1.200602
# 1     2275195        75.142067      2275195     3.386464
#
#    std_bowler_strike_rate  recency_score_x  matches_played_x  total_runs  \
# 0                8.335030     1.690917e+09                 5          90
# 1                6.131763     1.702668e+09                 5         191
#
#    total_balls_faced   recent_sr  bowler_id_y  recency_score_y  \
# 0                 55  163.636364      4171460     1.690554e+09
# 1                 99  192.929293      2275195     1.699678e+09
#
#    matches_played_y  total_wickets  total_runs_conceded  \
# 0                 5              5                  140
# 1                 5              5                  146
#
#    average_runs_conceded  cumulative_runs  half_centuries  centuries  \
# 0                   28.0              400               0          0
# 1                   29.2             2480              17          3
#
#    matches_x  strike_rate    average  score_strike  score_half_centuries  \
# 0         27   103.976667  14.814815            40                     0
# 1         95   126.458211  26.105263            40                    20
#
#    score_centuries  score_average  total_score  bowler_id  cumulative_wickets  \
# 0                0              5           45    4171460                  21
# 1               30              5           95    2275195                  36
#
#    balls_bowled  runs_given  count_4w_per_inning  matches_y   economy  \
# 0           462         631                    1         26  8.708462
# 1           882        1154                    0         68  8.365588
#
#    strike_rate_bowl  average_bowl  score_strike_bowl  score_economy  \
# 0              22.0     30.047619                 10              0
# 1              24.5     32.055556                  0              0
#
#    score_average_bowl  score_4w  total_score_bowl  total_score_allround  \
# 0                  10        10                30                    75
# 1                  10         0                10                   105
#
#    total_score_normalised  std_sr_normalised  recent_sr_normalised  \
# 0                0.466667           0.838447              0.571044
# 1                0.666667           0.711155              0.683876
#
#    recent_matches_batsman  recent_matches_bowler  \
# 0                     1.0                    1.0
# 1                     1.0                    1.0
#
#    std_bowler_economy_normalised  recent_average_normalised       sum  \
# 0                       0.818858                     0.8250  5.520016
# 1                       0.489065                     0.8175  5.368262
#
#    Player_id
# 0    4171460
# 1    2275195

# %% [markdown]
# # ADDING BEST 11 PLAYERS TO FILE

# %%
my11_batsman2 = final_sorted.head(3)['batsman_id']
my11_batsman = final_sorted.head(3).reset_index(drop=True)
final_sorted.head(3)
# Out:
#      batsman_id  std_strike_rate  recency_score  matches_played  total_runs  \
# 183     2275195        75.142067   1.702668e+09               5         191
# 164     2162782        58.786308   1.697103e+09               5         233
# 180     2263736        43.395586   1.680670e+09               5         179
#
#      total_balls_faced   recent_sr  cumulative_runs  half_centuries  \
# 183                 99  192.929293             2480              17
# 164                149  156.375839             3498              32
# 180                134  133.582090             4031              40
#
#      centuries  matches  strike_rate    average  score_strike  \
# 183          3       95   126.458211  26.105263            40
# 164          6       97   123.307835  36.061856            40
# 180          2       92   115.673261  43.815217            40
#
#      score_half_centuries  score_centuries  score_average  total_score  \
# 183                    20               30              5           95
# 164                    20               30             10          100
# 180                    20               20             20          100
#
#      total_score_normalised  std_sr_normalised  recent_sr_normalised  \
# 183                0.947368           0.644981              0.828428
# 164                1.000000           0.739542              0.652468
# 180                1.000000           0.828523              0.542745
#
#      recent_matches_played       sum
# 183                    1.0  3.420777
# 164                    1.0  3.392010
# 180                    1.0  3.371268

# %%
my11_wicketkeeper = final_sorted_wk[~final_sorted_wk['batsman_id'].isin(my11_batsman2)]
my11_wicketkeeper.head(1)
# Out:
#      batsman_id  std_strike_rate  recency_score  matches_played  total_runs  \
# 108     4685568        60.998638   1.696861e+09               5         249
#
#      total_balls_faced   recent_sr  cumulative_runs  half_centuries  \
# 108                122  204.098361             2525              15
#
#      centuries  matches  strike_rate  is_batsman_keeper    average  \
# 108          1      105   132.002952                 63  24.047619
#
#      score_strike  score_half_centuries  score_centuries  score_average  \
# 108            40                    20               10              5
#
#      total_score  total_score_normalised  std_sr_normalised  \
# 108           75                0.736842           0.427675
#
#      recent_sr_normalised  recent_matches_played       sum
# 108              0.879994                    1.0  3.044512

# %%
my11_bowler2 = final_sorted_bowler.head(3)['bowler_id']
my11_bowler = final_sorted_bowler.head(3).reset_index(drop=True)
final_sorted_bowler.head(3)
# Out:
#      bowler_id  std_economy  std_bowler_strike_rate  recency_score  \
# 463    8246440     1.534747                7.970315   1.698123e+09
# 202    3633503     1.134196                7.277820   1.692818e+09
# 464    8246573     1.832357                6.231401   1.689708e+09
#
#      matches_played  total_wickets  total_runs_conceded  \
# 463               5              9                   97
# 202               5              8                   93
# 464               5             10                  125
#
#      average_runs_conceded  cumulative_wickets  balls_bowled  runs_given  \
# 463              10.777778                  23           247         214
# 202              11.625000                  11           174         163
# 464              12.500000                  14           151         167
#
#      count_4w_per_inning  matches  economy  strike_rate_bowl  average_bowl  \
# 463                    1       12    5.320         10.739130      9.304348
# 202                    0       10    5.841         15.818182     14.818182
# 464                    0        7    6.820         10.785714     11.928571
#
#      score_strike_bowl  score_economy  score_average_bowl  score_4w  \
# 463                 30             30                  30        10
# 202                 20             30                  30         0
# 464                 30             30                  30         0
#
#      total_score_bowl  total_score_bowler_normalised  \
# 463               100                            1.0
# 202                80                            0.8
# 464                90                            0.9
#
#      std_bowler_economy_normalised  recent_average_normalised       sum
# 463                       0.830737                   0.932639  2.763375
# 202                       0.936345                   0.927344  2.663688
# 464                       0.752270                   0.921875  2.574145

# %%
my11_allrounder = final_sorted_allrounder[~final_sorted_allrounder['batsman_id'].isin(my11_batsman2)]
my11_allrounder2 = my11_allrounder[~my11_allrounder['bowler_id'].isin(my11_bowler2)]
my11_allrounder2.head(4)
# Out:
#      batsman_id  std_strike_rate  bowler_id_x  std_economy  \
# 273     3298427        62.424451      3298427     1.555194
# 675     7906968        64.830608      7906968     1.705561
# 438     4739552        87.461390      4739552     2.140649
# 536     6282856        69.010822      6282856     1.895994
#
#      std_bowler_strike_rate  recency_score_x  matches_played_x  total_runs  \
# 273                5.201398     1.687807e+09                 5          98
# 675                4.516636     1.698175e+09                 5         132
# 438                5.201343     1.693492e+09                 5          80
# 536                7.250616     1.697397e+09                 5          80
#
#      total_balls_faced   recent_sr  bowler_id_y  recency_score_y  \
# 273                 68  144.117647      3298427     1.687236e+09
# 675                 96  137.500000      7906968     1.698175e+09
# 438                 35  228.571429      4739552     1.694598e+09
# 536                 49  163.265306      6282856     1.688964e+09
#
#      matches_played_y  total_wickets  total_runs_conceded  \
# 273                 5              4                  103
# 675                 5              8                   99
# 438                 5              5                  113
# 536                 5              5                   82
#
#      average_runs_conceded  cumulative_runs  half_centuries  centuries  \
# 273                 25.750              762               5          0
# 675                 12.375              493               2          0
# 438                 22.600              573               1          0
# 536                 16.400             2150              17          1
#
#      matches_x  strike_rate    average  score_strike  score_half_centuries  \
# 273         31   111.541613  24.580645            40                    20
# 675         18   118.297778  27.388889            40                     5
# 438         37   124.874054  15.486486            40                     5
# 536         80   131.639250  26.875000            40                    20
#
#      score_centuries  score_average  total_score  bowler_id  \
# 273                0              5           65    3298427
# 675                0              5           50    7906968
# 438                0              5           50    4739552
# 536               10              5           75    6282856
#
#      cumulative_wickets  balls_bowled  runs_given  count_4w_per_inning  \
# 273                  23           352         399                    0
# 675                  17           264         295                    0
# 438                  63           874        1318                    1
# 536                  21           340         410                    0
#
#      matches_y   economy  strike_rate_bowl  average_bowl  score_strike_bowl  \
# 273         23  6.833043         15.304348     17.347826                 20
# 675         14  6.536429         15.529412     17.352941                 20
# 438         49  9.219796         13.873016     20.920635                 30
# 536         30  7.833000         16.190476     19.523810                 20
#
#      score_economy  score_average_bowl  score_4w  total_score_bowl  \
# 273             30                  30         0                80
# 675             30                  30         0                80
# 438              0                  20        10                60
# 536              0                  30         0                50
#
#      total_score_allround  total_score_normalised  std_sr_normalised  \
# 273                   145                0.933333           0.763023
# 675                   130                0.833333           0.753210
# 438                   110                0.700000           0.660911
# 536                   125                0.800000           0.736161
#
#      recent_sr_normalised  recent_matches_batsman  recent_matches_bowler  \
# 273              0.495861                     1.0                    1.0
# 675              0.470370                     1.0                    1.0
# 438              0.821164                     1.0                    1.0
# 536              0.569615                     1.0                    1.0
#
#      std_bowler_economy_normalised  recent_average_normalised       sum
# 273                       0.765359                   0.839063  5.796639
# 675                       0.742672                   0.922656  5.722242
# 438                       0.677028                   0.858750  5.717853
# 536                       0.713941                   0.897500  5.717216

# %%
nearbest_11
# Out:
#     Player_id
# 0      325814
# 1     1626526
# 2     1506098
# 3       82228
# 4     8250115
# 5     4171460
# 6     2275195
# 7     5652758
# 8     8986193
# 9     8246573
# 10    7758638

# %%
my11_pandas = pd.read_csv("my11_from_pandas2.csv")
my11_pandas.head()
# Out:
# Empty DataFrame
# Columns: [player_id, total_points, role, runs, batting_strike_rate, batting_average, 100s, 50s, wickets, bowling_strike_rate, economy, bowling_average, 4w_per_innings]
# Index: []

# %%
batsman_appending = my11_batsman[['batsman_id', 'total_score', 'cumulative_runs', 'strike_rate', 'average', 'centuries', 'half_centuries']]
batsman_appending.columns = ['player_id', 'total_points', 'runs', 'batting_strike_rate', 'batting_average', '100s', '50s']

batsman_appending['role'] = 'batsman'

bat_my11_pandas = pd.concat([my11_pandas, batsman_appending], ignore_index=True)
bat_my11_pandas
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13712\961984223.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batsman_appending['role'] = 'batsman'
#   player_id total_points     role  runs  batting_strike_rate  batting_average  \
# 0   2275195           95  batsman  2480           126.458211        26.105263
# 1   2162782          100  batsman  3498           123.307835        36.061856
# 2   2263736          100  batsman  4031           115.673261        43.815217
#
#   100s 50s wickets bowling_strike_rate economy bowling_average 4w_per_innings
# 0    3  17     NaN                 NaN     NaN             NaN            NaN
# 1    6  32     NaN                 NaN     NaN             NaN            NaN
# 2    2  40     NaN                 NaN     NaN             NaN            NaN

# %%
wk_appending = my11_wicketkeeper.head(1)[['batsman_id', 'total_score', 'cumulative_runs', 'strike_rate', 'average', 'centuries', 'half_centuries']]
wk_appending.columns = ['player_id', 'total_points', 'runs', 'batting_strike_rate', 'batting_average', '100s', '50s']

wk_appending['role'] = 'wicketkeeper'

wk_my11_pandas = pd.concat([bat_my11_pandas, wk_appending], ignore_index=True)
wk_my11_pandas
# Out:
#   player_id total_points          role  runs  batting_strike_rate  \
# 0   2275195           95       batsman  2480           126.458211
# 1   2162782          100       batsman  3498           123.307835
# 2   2263736          100       batsman  4031           115.673261
# 3   4685568           75  wicketkeeper  2525           132.002952
#
#    batting_average 100s 50s wickets bowling_strike_rate economy  \
# 0        26.105263    3  17     NaN                 NaN     NaN
# 1        36.061856    6  32     NaN                 NaN     NaN
# 2        43.815217    2  40     NaN                 NaN     NaN
# 3        24.047619    1  15     NaN                 NaN     NaN
#
#   bowling_average 4w_per_innings
# 0             NaN            NaN
# 1             NaN            NaN
# 2             NaN            NaN
# 3             NaN            NaN

# %%
all_appending = my11_allrounder2.head(4)[['batsman_id', 'total_score_allround', 'cumulative_runs', 'strike_rate', 'average', 'centuries', 'half_centuries', 'cumulative_wickets', 'strike_rate_bowl', 'economy', 'average_bowl', 'count_4w_per_inning']]
all_appending.columns = ['player_id', 'total_points', 'runs', 'batting_strike_rate', 'batting_average', '100s', '50s','wickets', 'bowling_strike_rate', 'economy', 'bowling_average', '4w_per_innings']

all_appending['role'] = 'all-rounder'

all_my11_pandas = pd.concat([wk_my11_pandas, all_appending], ignore_index=True)
all_my11_pandas
# Out:
#   player_id total_points          role  runs  batting_strike_rate  \
# 0   2275195           95       batsman  2480           126.458211
# 1   2162782          100       batsman  3498           123.307835
# 2   2263736          100       batsman  4031           115.673261
# 3   4685568           75  wicketkeeper  2525           132.002952
# 4   3298427          145   all-rounder   762           111.541613
# 5   7906968          130   all-rounder   493           118.297778
# 6   4739552          110   all-rounder   573           124.874054
# 7   6282856          125   all-rounder  2150           131.639250
#
#    batting_average 100s 50s wickets  bowling_strike_rate   economy  \
# 0        26.105263    3  17     NaN                  NaN       NaN
# 1        36.061856    6  32     NaN                  NaN       NaN
# 2        43.815217    2  40     NaN                  NaN       NaN
# 3        24.047619    1  15     NaN                  NaN       NaN
# 4        24.580645    0   5      23            15.304348  6.833043
# 5        27.388889    0   2      17            15.529412  6.536429
# 6        15.486486    0   1      63            13.873016  9.219796
# 7        26.875000    1  17      21            16.190476  7.833000
#
#    bowling_average 4w_per_innings
# 0              NaN            NaN
# 1              NaN            NaN
# 2              NaN            NaN
# 3              NaN            NaN
# 4        17.347826              0
# 5        17.352941              0
# 6        20.920635              1
# 7        19.523810              0

# %%
ball_appending = my11_bowler.head(3)[['bowler_id', 'total_score_bowl', 'cumulative_wickets', 'strike_rate_bowl', 'economy', 'average_bowl', 'count_4w_per_inning']]
ball_appending.columns = ['player_id', 'total_points','wickets', 'bowling_strike_rate', 'economy', 'bowling_average', '4w_per_innings']

ball_appending['role'] = 'bowler'

final_my11_pandas = pd.concat([all_my11_pandas, ball_appending], ignore_index=True)
final_my11_pandas
# Out:
#    player_id total_points          role  runs  batting_strike_rate  \
# 0    2275195           95       batsman  2480           126.458211
# 1    2162782          100       batsman  3498           123.307835
# 2    2263736          100       batsman  4031           115.673261
# 3    4685568           75  wicketkeeper  2525           132.002952
# 4    3298427          145   all-rounder   762           111.541613
# 5    7906968          130   all-rounder   493           118.297778
# 6    4739552          110   all-rounder   573           124.874054
# 7    6282856          125   all-rounder  2150           131.639250
# 8    8246440          100        bowler   NaN                  NaN
# 9    3633503           80        bowler   NaN                  NaN
# 10   8246573           90        bowler   NaN                  NaN
#
#     batting_average 100s  50s wickets  bowling_strike_rate   economy  \
# 0         26.105263    3   17     NaN                  NaN       NaN
# 1         36.061856    6   32     NaN                  NaN       NaN
# 2         43.815217    2   40     NaN                  NaN       NaN
# 3         24.047619    1   15     NaN                  NaN       NaN
# 4         24.580645    0    5      23            15.304348  6.833043
# 5         27.388889    0    2      17            15.529412  6.536429
# 6         15.486486    0    1      63            13.873016  9.219796
# 7         26.875000    1   17      21            16.190476  7.833000
# 8               NaN  NaN  NaN      23            10.739130  5.320000
# 9               NaN  NaN  NaN      11            15.818182  5.841000
# 10              NaN  NaN  NaN      14            10.785714  6.820000
#
#     bowling_average 4w_per_innings
# 0               NaN            NaN
# 1               NaN            NaN
# 2               NaN            NaN
# 3               NaN            NaN
# 4         17.347826              0
# 5         17.352941              0
# 6         20.920635              1
# 7         19.523810              0
# 8          9.304348              1
# 9         14.818182              0
# 10        11.928571              0

# %%
final_my11_pandas.to_csv('my11_from_pandas2.csv', index=False, encoding='utf-8')
